# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for i in range(len(reviews)):
    if (labels[i] == 'POSITIVE'):
        for word in reviews[i].split(" "):
            total_counts[word] += 1
            positive_counts[word] +=1
    elif (labels[i] == 'NEGATIVE'):
        for word in reviews[i].split(" "):
            total_counts[word] += 1
            negative_counts[word] +=1

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 550468),
#  ('the', 173324),
#  ('.', 159654),
#  ('and', 89722),
#  ('a', 83688),
#  ('of', 76855),
#  ('to', 66746),
#  ('is', 57245),
#  ('in', 50215),
#  ('br', 49235),
#  ('it', 48025),
#  ('i', 40743),
#  ('that', 35630),
#  ('this', 35080),
#  ('s', 33815),
#  ('as', 26308),
#  ('with', 23247),
#  ('for', 22416),
#  ('was', 21917),
#  ('film', 20937),
#  ('but', 20822),
#  ('movie', 19074),
#  ('his', 17227),
#  ('on', 17008),
#  ('you', 16681),
#  ('he', 16282),
#  ('are', 14807),
#  ('not', 14272),
#  ('t', 13720),
#  ('one', 13655),
#  ('have', 12587),
#  ('be', 12416),
#  ('by', 11997),
#  ('all', 11942),
#  ('who', 11464),
#  ('an', 11294),
#  ('at', 11234),
#  ('from', 10767),
#  ('her', 10474),
#  ('they', 9895),
#  ('has', 9186),
#  ('so', 9154),
#  ('like', 9038),
#  ('about', 8313),
#  ('very', 8305),
#  ('out', 8134),
#  ('there', 8057),
#  ('she', 7779),
#  ('what', 7737),
#  ('or', 7732),
#  ('good', 7720),
#  ('more', 7521),
#  ('when', 7456),
#  ('some', 7441),
#  ('if', 7285),
#  ('just', 7152),
#  ('can', 7001),
#  ('story', 6780),
#  ('time', 6515),
#  ('my', 6488),
#  ('great', 6419),
#  ('well', 6405),
#  ('up', 6321),
#  ('which', 6267),
#  ('their', 6107),
#  ('see', 6026),
#  ('also', 5550),
#  ('we', 5531),
#  ('really', 5476),
#  ('would', 5400),
#  ('will', 5218),
#  ('me', 5167),
#  ('had', 5148),
#  ('only', 5137),
#  ('him', 5018),
#  ('even', 4964),
#  ('most', 4864),
#  ('other', 4858),
#  ('were', 4782),
#  ('first', 4755),
#  ('than', 4736),
#  ('much', 4685),
#  ('its', 4622),
#  ('no', 4574),
#  ('into', 4544),
#  ('people', 4479),
#  ('best', 4319),
#  ('love', 4301),
#  ('get', 4272),
#  ('how', 4213),
#  ('life', 4199),
#  ('been', 4189),
#  ('because', 4079),
#  ('way', 4036),
#  ('do', 3941),
#  ('made', 3823),
#  ('films', 3813),
#  ('them', 3805),
#  ('after', 3800),
#  ('many', 3766),
#  ('two', 3733),
#  ('too', 3659),
#  ('think', 3655),
#  ('movies', 3586),
#  ('characters', 3560),
#  ('character', 3514),
#  ('don', 3468),
#  ('man', 3460),
#  ('show', 3432),
#  ('watch', 3424),
#  ('seen', 3414),
#  ('then', 3358),
#  ('little', 3341),
#  ('still', 3340),
#  ('make', 3303),
#  ('could', 3237),
#  ('never', 3226),
#  ('being', 3217),
#  ('where', 3173),
#  ('does', 3069),
#  ('over', 3017),
#  ('any', 3002),
#  ('while', 2899),
#  ('know', 2833),
#  ('did', 2790),
#  ('years', 2758),
#  ('here', 2740),
#  ('ever', 2734),
#  ('end', 2696),
#  ('these', 2694),
#  ('such', 2590),
#  ('real', 2568),
#  ('scene', 2567),
#  ('back', 2547),
#  ('those', 2485),
#  ('though', 2475),
#  ('off', 2463),
#  ('new', 2458),
#  ('your', 2453),
#  ('go', 2440),
#  ('acting', 2437),
#  ('plot', 2432),
#  ('world', 2429),
#  ('scenes', 2427),
#  ('say', 2414),
#  ('through', 2409),
#  ('makes', 2390),
#  ('better', 2381),
#  ('now', 2368),
#  ('work', 2346),
#  ('young', 2343),
#  ('old', 2311),
#  ('ve', 2307),
#  ('find', 2272),
#  ('both', 2248),
#  ('before', 2177),
#  ('us', 2162),
#  ('again', 2158),
#  ('series', 2153),
#  ('quite', 2143),
#  ('something', 2135),
#  ('cast', 2133),
#  ('should', 2121),
#  ('part', 2098),
#  ('always', 2088),
#  ('lot', 2087),
#  ('another', 2075),
#  ('actors', 2047),
#  ('director', 2040),
#  ('family', 2032),
#  ('between', 2016),
#  ('own', 2016),
#  ('m', 1998),
#  ('may', 1997),
#  ('same', 1972),
#  ('role', 1967),
#  ('watching', 1966),
#  ('every', 1954),
#  ('funny', 1953),
#  ('doesn', 1935),
#  ('performance', 1928),
#  ('few', 1918),
#  ('bad', 1907),
#  ('look', 1900),
#  ('re', 1884),
#  ('why', 1855),
#  ('things', 1849),
#  ('times', 1832),
#  ('big', 1815),
#  ('however', 1795),
#  ('actually', 1790),
#  ('action', 1789),
#  ('going', 1783),
#  ('bit', 1757),
#  ('comedy', 1742),
#  ('down', 1740),
#  ('music', 1738),
#  ('must', 1728),
#  ('take', 1709),
#  ('saw', 1692),
#  ('long', 1690),
#  ('right', 1688),
#  ('fun', 1686),
#  ('fact', 1684),
#  ('excellent', 1683),
#  ('around', 1674),
#  ('didn', 1672),
#  ('without', 1671),
#  ('thing', 1662),
#  ('thought', 1639),
#  ('got', 1635),
#  ('each', 1630),
#  ('day', 1614),
#  ('feel', 1597),
#  ('seems', 1596),
#  ('come', 1594),
#  ('done', 1586),
#  ('beautiful', 1580),
#  ('especially', 1572),
#  ('played', 1571),
#  ('almost', 1566),
#  ('want', 1562),
#  ('yet', 1556),
#  ('give', 1553),
#  ('pretty', 1549),
#  ('last', 1543),
#  ('since', 1519),
#  ('different', 1504),
#  ('although', 1501),
#  ('gets', 1490),
#  ('true', 1487),
#  ('interesting', 1481),
#  ('job', 1470),
#  ('enough', 1455),
#  ('our', 1454),
#  ('shows', 1447),
#  ('horror', 1441),
#  ('woman', 1439),
#  ('tv', 1400),
#  ('probably', 1398),
#  ('father', 1395),
#  ('original', 1393),
#  ('girl', 1390),
#  ('point', 1379),
#  ('plays', 1378),
#  ('wonderful', 1372),
#  ('far', 1358),
#  ('course', 1358),
#  ('john', 1350),
#  ('rather', 1340),
#  ('isn', 1328),
#  ('ll', 1326),
#  ('later', 1324),
#  ('dvd', 1324),
#  ('whole', 1310),
#  ('war', 1310),
#  ('d', 1307),
#  ('found', 1306),
#  ('away', 1306),
#  ('screen', 1305),
#  ('nothing', 1300),
#  ('year', 1297),
#  ('once', 1296),
#  ('hard', 1294),
#  ('together', 1280),
#  ('set', 1277),
#  ('am', 1277),
#  ('having', 1266),
#  ('making', 1265),
#  ('place', 1263),
#  ('might', 1260),
#  ('comes', 1260),
#  ('sure', 1253),
#  ('american', 1248),
#  ('play', 1245),
#  ('kind', 1244),
#  ('perfect', 1242),
#  ('takes', 1242),
#  ('performances', 1237),
#  ('himself', 1230),
#  ('worth', 1221),
#  ('everyone', 1221),
#  ('anyone', 1214),
#  ('actor', 1203),
#  ('three', 1201),
#  ('wife', 1196),
#  ('classic', 1192),
#  ('goes', 1186),
#  ('ending', 1178),
#  ('version', 1168),
#  ('star', 1149),
#  ('enjoy', 1146),
#  ('book', 1142),
#  ('nice', 1132),
#  ('everything', 1128),
#  ('during', 1124),
#  ('put', 1118),
#  ('seeing', 1111),
#  ('least', 1102),
#  ('house', 1100),
#  ('high', 1095),
#  ('watched', 1094),
#  ('loved', 1087),
#  ('men', 1087),
#  ('night', 1082),
#  ('anything', 1075),
#  ('believe', 1071),
#  ('guy', 1071),
#  ('top', 1063),
#  ('amazing', 1058),
#  ('hollywood', 1056),
#  ('looking', 1053),
#  ('main', 1044),
#  ('definitely', 1043),
#  ('gives', 1031),
#  ('home', 1029),
#  ('seem', 1028),
#  ('episode', 1023),
#  ('audience', 1020),
#  ('sense', 1020),
#  ('truly', 1017),
#  ('special', 1011),
#  ('second', 1009),
#  ('short', 1009),
#  ('fan', 1009),
#  ('mind', 1005),
#  ('human', 1001),
#  ('recommend', 999),
#  ('full', 996),
#  ('black', 995),
#  ('help', 991),
#  ('along', 989),
#  ('trying', 987),
#  ('small', 986),
#  ('death', 985),
#  ('friends', 981),
#  ('remember', 974),
#  ('often', 970),
#  ('said', 966),
#  ('favorite', 962),
#  ('heart', 959),
#  ('early', 957),
#  ('left', 956),
#  ('until', 955),
#  ('script', 954),
#  ('let', 954),
#  ('maybe', 937),
#  ('today', 936),
#  ('live', 934),
#  ('less', 934),
#  ('moments', 933),
#  ('others', 929),
#  ('brilliant', 926),
#  ('shot', 925),
#  ('liked', 923),
#  ('become', 916),
#  ('won', 915),
#  ('used', 910),
#  ('style', 907),
#  ('mother', 895),
#  ('lives', 894),
#  ('came', 893),
#  ('stars', 890),
#  ('cinema', 889),
#  ('looks', 885),
#  ('perhaps', 884),
#  ('read', 882),
#  ('enjoyed', 879),
#  ('boy', 875),
#  ('drama', 873),
#  ('highly', 871),
#  ('given', 870),
#  ('playing', 867),
#  ('use', 864),
#  ('next', 859),
#  ('women', 858),
#  ('fine', 857),
#  ('effects', 856),
#  ('kids', 854),
#  ('entertaining', 853),
#  ('need', 852),
#  ('line', 850),
#  ('works', 848),
#  ('someone', 847),
#  ('mr', 836),
#  ('simply', 835),
#  ('picture', 833),
#  ('children', 833),
#  ('face', 831),
#  ('keep', 831),
#  ('friend', 831),
#  ('dark', 830),
#  ('overall', 828),
#  ('certainly', 828),
#  ('minutes', 827),
#  ('wasn', 824),
#  ('history', 822),
#  ('finally', 820),
#  ('couple', 816),
#  ('against', 815),
#  ('son', 809),
#  ('understand', 808),
#  ('lost', 807),
#  ('michael', 805),
#  ('else', 801),
#  ('throughout', 798),
#  ('fans', 797),
#  ('city', 792),
#  ('reason', 789),
#  ('written', 787),
#  ('production', 787),
#  ('several', 784),
#  ('school', 783),
#  ('based', 781),
#  ('rest', 781),
#  ('try', 780),
#  ('dead', 776),
#  ('hope', 775),
#  ('strong', 768),
#  ('white', 765),
#  ('tell', 759),
#  ('itself', 758),
#  ('half', 753),
#  ('person', 749),
#  ('sometimes', 746),
#  ('past', 744),
#  ('start', 744),
#  ('genre', 743),
#  ('beginning', 739),
#  ('final', 739),
#  ('town', 738),
#  ('art', 734),
#  ('humor', 732),
#  ('game', 732),
#  ('yes', 731),
#  ('idea', 731),
#  ('late', 730),
#  ('becomes', 729),
#  ('despite', 729),
#  ('able', 726),
#  ('case', 726),
#  ('money', 723),
#  ('child', 721),
#  ('completely', 721),
#  ('side', 719),
#  ('camera', 716),
#  ('getting', 714),
#  ('instead', 712),
#  ('soon', 702),
#  ('under', 700),
#  ('viewer', 699),
#  ('age', 697),
#  ('days', 696),
#  ('stories', 696),
#  ('felt', 694),
#  ('simple', 694),
#  ('roles', 693),
#  ('video', 688),
#  ('name', 683),
#  ('either', 683),
#  ('doing', 677),
#  ('turns', 674),
#  ('wants', 671),
#  ('close', 671),
#  ('title', 669),
#  ('wrong', 668),
#  ('went', 666),
#  ('james', 665),
#  ('evil', 659),
#  ('budget', 657),
#  ('episodes', 657),
#  ('relationship', 655),
#  ('fantastic', 653),
#  ('piece', 653),
#  ('david', 651),
#  ('turn', 648),
#  ('murder', 646),
#  ('parts', 645),
#  ('brother', 644),
#  ('absolutely', 643),
#  ('head', 643),
#  ('experience', 642),
#  ('eyes', 641),
#  ('sex', 638),
#  ('direction', 637),
#  ('called', 637),
#  ('directed', 636),
#  ('lines', 634),
#  ('behind', 633),
#  ('sort', 632),
#  ('actress', 631),
#  ('lead', 630),
#  ('oscar', 628),
#  ('including', 627),
#  ('example', 627),
#  ('known', 625),
#  ('musical', 625),
#  ('chance', 621),
#  ('score', 620),
#  ('already', 619),
#  ('feeling', 619),
#  ('hit', 619),
#  ('voice', 615),
#  ('moment', 612),
#  ('living', 612),
#  ('low', 610),
#  ('supporting', 610),
#  ('ago', 609),
#  ('themselves', 608),
#  ('reality', 605),
#  ('hilarious', 605),
#  ('jack', 604),
#  ('told', 603),
#  ('hand', 601),
#  ('quality', 600),
#  ('moving', 600),
#  ('dialogue', 600),
#  ('song', 599),
#  ('happy', 599),
#  ('matter', 598),
#  ('paul', 598),
#  ('light', 594),
#  ('future', 593),
#  ('entire', 592),
#  ('finds', 591),
#  ('gave', 589),
#  ('laugh', 587),
#  ('released', 586),
#  ('expect', 584),
#  ('fight', 581),
#  ('particularly', 580),
#  ('cinematography', 579),
#  ('police', 579),
#  ('whose', 578),
#  ('type', 578),
#  ('sound', 578),
#  ('view', 573),
#  ('enjoyable', 573),
#  ('number', 572),
#  ('romantic', 572),
#  ('husband', 572),
#  ('daughter', 572),
#  ('documentary', 571),
#  ('self', 570),
#  ('superb', 569),
#  ('modern', 569),
#  ('took', 569),
#  ('robert', 569),
#  ('mean', 566),
#  ('shown', 563),
#  ('coming', 561),
#  ('important', 560),
#  ('king', 559),
#  ('leave', 559),
#  ('change', 558),
#  ('somewhat', 555),
#  ('wanted', 555),
#  ('tells', 554),
#  ('events', 552),
#  ('run', 552),
#  ('career', 552),
#  ('country', 552),
#  ('heard', 550),
#  ('season', 550),
#  ('greatest', 549),
#  ('girls', 549),
#  ('etc', 547),
#  ('care', 546),
#  ('starts', 545),
#  ('english', 542),
#  ('killer', 541),
#  ('tale', 540),
#  ('guys', 540),
#  ('totally', 540),
#  ('animation', 540),
#  ('usual', 539),
#  ('miss', 535),
#  ('opinion', 535),
#  ('easy', 531),
#  ('violence', 531),
#  ('songs', 530),
#  ('british', 528),
#  ('says', 526),
#  ('realistic', 525),
#  ('writing', 524),
#  ('writer', 522),
#  ('act', 522),
#  ('comic', 521),
#  ('thriller', 519),
#  ('television', 517),
#  ('power', 516),
#  ('ones', 515),
#  ('kid', 514),
#  ('york', 513),
#  ('novel', 513),
#  ('alone', 512),
#  ('problem', 512),
#  ('attention', 509),
#  ('involved', 508),
#  ('kill', 507),
#  ('extremely', 507),
#  ('seemed', 506),
#  ('hero', 505),
#  ('french', 505),
#  ('rock', 504),
#  ('stuff', 501),
#  ('wish', 499),
#  ('begins', 498),
#  ('taken', 497),
#  ('sad', 497),
#  ('ways', 496),
#  ('richard', 495),
#  ('knows', 494),
#  ('atmosphere', 493),
#  ('similar', 491),
#  ('surprised', 491),
#  ('taking', 491),
#  ('car', 491),
#  ('george', 490),
#  ('perfectly', 490),
#  ('across', 489),
#  ('team', 489),
#  ('eye', 489),
#  ('sequence', 489),
#  ('room', 488),
#  ('due', 488),
#  ('among', 488),
#  ('serious', 488),
#  ('powerful', 488),
#  ('strange', 487),
#  ('order', 487),
#  ('cannot', 487),
#  ('b', 487),
#  ('beauty', 486),
#  ('famous', 485),
#  ('happened', 484),
#  ('tries', 484),
#  ('herself', 484),
#  ('myself', 484),
#  ('class', 483),
#  ('four', 482),
#  ('cool', 481),
#  ('release', 479),
#  ('anyway', 479),
#  ('theme', 479),
#  ('opening', 478),
#  ('entertainment', 477),
#  ('slow', 475),
#  ('ends', 475),
#  ('unique', 475),
#  ('exactly', 475),
#  ('easily', 474),
#  ('level', 474),
#  ('o', 474),
#  ('red', 474),
#  ('interest', 472),
#  ('happen', 471),
#  ('crime', 470),
#  ('viewing', 468),
#  ('sets', 467),
#  ('memorable', 467),
#  ('stop', 466),
#  ('group', 466),
#  ('problems', 463),
#  ('dance', 463),
#  ('working', 463),
#  ('sister', 463),
#  ('message', 463),
#  ('knew', 462),
#  ('mystery', 461),
#  ('nature', 461),
#  ('bring', 460),
#  ('believable', 459),
#  ('thinking', 459),
#  ('brought', 459),
#  ('mostly', 458),
#  ('disney', 457),
#  ('couldn', 457),
#  ('society', 456),
#  ('lady', 455),
#  ('within', 455),
#  ('blood', 454),
#  ('parents', 453),
#  ('upon', 453),
#  ('viewers', 453),
#  ('meets', 452),
#  ('form', 452),
#  ('peter', 452),
#  ('tom', 452),
#  ('usually', 452),
#  ('soundtrack', 452),
#  ('local', 450),
#  ('certain', 448),
#  ('follow', 448),
#  ('whether', 447),
#  ('possible', 446),
#  ('emotional', 445),
#  ('killed', 444),
#  ('above', 444),
#  ('de', 444),
#  ('god', 443),
#  ('middle', 443),
#  ('needs', 442),
#  ('happens', 442),
#  ('flick', 442),
#  ('masterpiece', 441),
#  ('period', 440),
#  ('major', 440),
#  ('named', 439),
#  ('haven', 439),
#  ('particular', 438),
#  ('th', 438),
#  ('earth', 437),
#  ('feature', 437),
#  ('stand', 436),
#  ('words', 435),
#  ('typical', 435),
#  ('elements', 433),
#  ('obviously', 433),
#  ('romance', 431),
#  ('jane', 430),
#  ('yourself', 427),
#  ('showing', 427),
#  ('brings', 426),
#  ('fantasy', 426),
#  ('guess', 423),
#  ('america', 423),
#  ('unfortunately', 422),
#  ('huge', 422),
#  ('indeed', 421),
#  ('running', 421),
#  ('talent', 420),
#  ('stage', 419),
#  ('started', 418),
#  ('leads', 417),
#  ('sweet', 417),
#  ('japanese', 417),
#  ('poor', 416),
#  ('deal', 416),
#  ('incredible', 413),
#  ('personal', 413),
#  ('fast', 412),
#  ('became', 410),
#  ('deep', 410),
#  ('hours', 409),
#  ('giving', 408),
#  ('nearly', 408),
#  ('dream', 408),
#  ('clearly', 407),
#  ('turned', 407),
#  ('obvious', 406),
#  ('near', 406),
#  ('cut', 405),
#  ('surprise', 405),
#  ('era', 404),
#  ('body', 404),
#  ('hour', 403),
#  ('female', 403),
#  ('five', 403),
#  ('note', 399),
#  ('learn', 398),
#  ('truth', 398),
#  ('except', 397),
#  ('feels', 397),
#  ('match', 397),
#  ('tony', 397),
#  ('filmed', 394),
#  ('clear', 394),
#  ('complete', 394),
#  ('street', 393),
#  ('eventually', 393),
#  ('keeps', 393),
#  ('older', 393),
#  ('lots', 393),
#  ('buy', 392),
#  ('william', 391),
#  ('stewart', 391),
#  ('fall', 390),
#  ('joe', 390),
#  ('meet', 390),
#  ('unlike', 389),
#  ('talking', 389),
#  ('shots', 389),
#  ('rating', 389),
#  ('difficult', 389),
#  ('dramatic', 388),
#  ('means', 388),
#  ('situation', 386),
#  ('wonder', 386),
#  ('present', 386),
#  ('appears', 386),
#  ('subject', 386),
#  ('comments', 385),
#  ('general', 383),
#  ('sequences', 383),
#  ('lee', 383),
#  ('points', 382),
#  ('earlier', 382),
#  ('gone', 379),
#  ('check', 379),
#  ('suspense', 378),
#  ('recommended', 378),
#  ('ten', 378),
#  ('third', 377),
#  ('business', 377),
#  ('talk', 375),
#  ('leaves', 375),
#  ('beyond', 375),
#  ('portrayal', 374),
#  ('beautifully', 373),
#  ('single', 372),
#  ('bill', 372),
#  ('plenty', 371),
#  ('word', 371),
#  ('whom', 370),
#  ('falls', 370),
#  ('scary', 369),
#  ('non', 369),
#  ('figure', 369),
#  ('battle', 369),
#  ('using', 368),
#  ('return', 368),
#  ('doubt', 367),
#  ('add', 367),
#  ('hear', 366),
#  ('solid', 366),
#  ('success', 366),
#  ('jokes', 365),
#  ('oh', 365),
#  ('touching', 365),
#  ('political', 365),
#  ('hell', 364),
#  ('awesome', 364),
#  ('boys', 364),
#  ('sexual', 362),
#  ('recently', 362),
#  ('dog', 362),
#  ('please', 361),
#  ('wouldn', 361),
#  ('straight', 361),
#  ('features', 361),
#  ('forget', 360),
#  ('setting', 360),
#  ('lack', 360),
#  ('married', 359),
#  ('mark', 359),
#  ('social', 357),
#  ('interested', 356),
#  ('adventure', 356),
#  ('actual', 355),
#  ('terrific', 355),
#  ('sees', 355),
#  ('brothers', 355),
#  ('move', 354),
#  ('call', 354),
#  ('various', 353),
#  ('theater', 353),
#  ('dr', 353),
#  ('animated', 352),
#  ('western', 351),
#  ('baby', 350),
#  ('space', 350),
#  ('leading', 348),
#  ('disappointed', 348),
#  ('portrayed', 346),
#  ('aren', 346),
#  ('screenplay', 345),
#  ('smith', 345),
#  ('towards', 344),
#  ('hate', 344),
#  ('noir', 343),
#  ('outstanding', 342),
#  ('decent', 342),
#  ('kelly', 342),
#  ('directors', 341),
#  ('journey', 341),
#  ('none', 340),
#  ('looked', 340),
#  ('effective', 340),
#  ('storyline', 339),
#  ('caught', 339),
#  ('sci', 339),
#  ('fi', 339),
#  ('cold', 339),
#  ('mary', 339),
#  ('rich', 338),
#  ('charming', 338),
#  ('popular', 337),
#  ('rare', 337),
#  ('manages', 337),
#  ('harry', 337),
#  ('spirit', 336),
#  ('appreciate', 335),
#  ('open', 335),
#  ('moves', 334),
#  ('basically', 334),
#  ('acted', 334),
#  ('inside', 333),
#  ('boring', 333),
#  ('century', 333),
#  ('mention', 333),
#  ('deserves', 333),
#  ('subtle', 333),
#  ('pace', 333),
#  ('familiar', 332),
#  ('background', 332),
#  ('ben', 331),
#  ('creepy', 330),
#  ('supposed', 330),
#  ('secret', 329),
#  ('die', 328),
#  ('jim', 328),
#  ('question', 327),
#  ('effect', 327),
#  ('natural', 327),
#  ('impressive', 326),
#  ('rate', 326),
#  ('language', 326),
#  ('saying', 325),
#  ('intelligent', 325),
#  ('telling', 324),
#  ('realize', 324),
#  ('material', 324),
#  ('scott', 324),
#  ('singing', 323),
#  ('dancing', 322),
#  ('visual', 321),
#  ('adult', 321),
#  ('imagine', 321),
#  ('kept', 320),
#  ('office', 320),
#  ('uses', 319),
#  ('pure', 318),
#  ('wait', 318),
#  ('stunning', 318),
#  ('review', 317),
#  ('previous', 317),
#  ('copy', 317),
#  ('seriously', 317),
#  ('reading', 316),
#  ('create', 316),
#  ('hot', 316),
#  ('created', 316),
#  ('magic', 316),
#  ('somehow', 316),
#  ('stay', 315),
#  ('attempt', 315),
#  ('escape', 315),
#  ('crazy', 315),
#  ('air', 315),
#  ('frank', 315),
#  ('hands', 314),
#  ('filled', 313),
#  ('expected', 312),
#  ('average', 312),
#  ('surprisingly', 312),
#  ('complex', 311),
#  ('quickly', 310),
#  ('successful', 310),
#  ('studio', 310),
#  ('plus', 309),
#  ('male', 309),
#  ('co', 307),
#  ('images', 306),
#  ('casting', 306),
#  ('following', 306),
#  ('minute', 306),
#  ('exciting', 306),
#  ('members', 305),
#  ('follows', 305),
#  ('themes', 305),
#  ('german', 305),
#  ('reasons', 305),
#  ('e', 305),
#  ('touch', 304),
#  ('edge', 304),
#  ('free', 304),
#  ('cute', 304),
#  ('genius', 304),
#  ('outside', 303),
#  ('reviews', 302),
#  ('admit', 302),
#  ('ok', 302),
#  ('younger', 302),
#  ('fighting', 301),
#  ('odd', 301),
#  ('master', 301),
#  ('recent', 300),
#  ('thanks', 300),
#  ('break', 300),
#  ('comment', 300),
#  ('apart', 299),
#  ('emotions', 298),
#  ('lovely', 298),
#  ('begin', 298),
#  ('doctor', 297),
#  ('party', 297),
#  ('italian', 297),
#  ('la', 296),
#  ('missed', 296),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 561462),
#  ('.', 167538),
#  ('the', 163389),
#  ('a', 79321),
#  ('and', 74385),
#  ('of', 69009),
#  ('to', 68974),
#  ('br', 52637),
#  ('is', 50083),
#  ('it', 48327),
#  ('i', 46880),
#  ('in', 43753),
#  ('this', 40920),
#  ('that', 37615),
#  ('s', 31546),
#  ('was', 26291),
#  ('movie', 24965),
#  ('for', 21927),
#  ('but', 21781),
#  ('with', 20878),
#  ('as', 20625),
#  ('t', 20361),
#  ('film', 19218),
#  ('you', 17549),
#  ('on', 17192),
#  ('not', 16354),
#  ('have', 15144),
#  ('are', 14623),
#  ('be', 14541),
#  ('he', 13856),
#  ('one', 13134),
#  ('they', 13011),
#  ('at', 12279),
#  ('his', 12147),
#  ('all', 12036),
#  ('so', 11463),
#  ('like', 11238),
#  ('there', 10775),
#  ('just', 10619),
#  ('by', 10549),
#  ('or', 10272),
#  ('an', 10266),
#  ('who', 9969),
#  ('from', 9731),
#  ('if', 9518),
#  ('about', 9061),
#  ('out', 8979),
#  ('what', 8422),
#  ('some', 8306),
#  ('no', 8143),
#  ('her', 7947),
#  ('even', 7687),
#  ('can', 7653),
#  ('has', 7604),
#  ('good', 7423),
#  ('bad', 7401),
#  ('would', 7036),
#  ('up', 6970),
#  ('only', 6781),
#  ('more', 6730),
#  ('when', 6726),
#  ('she', 6444),
#  ('really', 6262),
#  ('time', 6209),
#  ('had', 6142),
#  ('my', 6015),
#  ('were', 6001),
#  ('which', 5780),
#  ('very', 5764),
#  ('me', 5606),
#  ('see', 5452),
#  ('don', 5336),
#  ('we', 5328),
#  ('their', 5278),
#  ('do', 5236),
#  ('story', 5208),
#  ('than', 5183),
#  ('been', 5100),
#  ('much', 5078),
#  ('get', 5037),
#  ('because', 4966),
#  ('people', 4806),
#  ('then', 4761),
#  ('make', 4722),
#  ('how', 4688),
#  ('could', 4686),
#  ('any', 4658),
#  ('into', 4567),
#  ('made', 4541),
#  ('first', 4306),
#  ('other', 4305),
#  ('well', 4254),
#  ('too', 4174),
#  ('them', 4165),
#  ('plot', 4154),
#  ('movies', 4080),
#  ('acting', 4056),
#  ('will', 3993),
#  ('way', 3989),
#  ('most', 3919),
#  ('him', 3858),
#  ('after', 3838),
#  ('its', 3655),
#  ('think', 3643),
#  ('also', 3608),
#  ('characters', 3600),
#  ('off', 3567),
#  ('watch', 3550),
#  ('character', 3506),
#  ('did', 3506),
#  ('why', 3463),
#  ('being', 3393),
#  ('better', 3358),
#  ('know', 3334),
#  ('over', 3316),
#  ('seen', 3265),
#  ('ever', 3263),
#  ('never', 3259),
#  ('your', 3233),
#  ('where', 3219),
#  ('two', 3173),
#  ('little', 3096),
#  ('films', 3077),
#  ('here', 3027),
#  ('m', 3000),
#  ('nothing', 2990),
#  ('say', 2982),
#  ('end', 2954),
#  ('something', 2942),
#  ('should', 2920),
#  ('many', 2909),
#  ('does', 2871),
#  ('thing', 2866),
#  ('show', 2862),
#  ('ve', 2829),
#  ('scene', 2816),
#  ('scenes', 2785),
#  ('these', 2724),
#  ('go', 2717),
#  ('didn', 2646),
#  ('great', 2640),
#  ('watching', 2640),
#  ('re', 2620),
#  ('doesn', 2601),
#  ('through', 2560),
#  ('such', 2544),
#  ('man', 2516),
#  ('worst', 2480),
#  ('actually', 2449),
#  ('actors', 2437),
#  ('life', 2429),
#  ('back', 2424),
#  ('while', 2418),
#  ('director', 2405),
#  ('funny', 2336),
#  ('going', 2319),
#  ('still', 2283),
#  ('another', 2254),
#  ('look', 2247),
#  ('now', 2237),
#  ('old', 2215),
#  ('those', 2212),
#  ('real', 2170),
#  ('few', 2158),
#  ('love', 2152),
#  ('horror', 2150),
#  ('before', 2147),
#  ('want', 2141),
#  ('minutes', 2126),
#  ('pretty', 2115),
#  ('best', 2094),
#  ('though', 2091),
#  ('same', 2081),
#  ('script', 2074),
#  ('work', 2027),
#  ('every', 2025),
#  ('seems', 2023),
#  ('least', 2011),
#  ('enough', 1997),
#  ('down', 1988),
#  ('original', 1983),
#  ('guy', 1964),
#  ('got', 1952),
#  ('around', 1943),
#  ('part', 1942),
#  ('lot', 1892),
#  ('anything', 1874),
#  ('find', 1860),
#  ('new', 1854),
#  ('again', 1849),
#  ('isn', 1849),
#  ('point', 1845),
#  ('things', 1839),
#  ('fact', 1839),
#  ('give', 1823),
#  ('makes', 1814),
#  ('take', 1800),
#  ('thought', 1798),
#  ('d', 1770),
#  ('whole', 1768),
#  ('long', 1761),
#  ('years', 1759),
#  ('however', 1740),
#  ('gets', 1714),
#  ('making', 1695),
#  ('cast', 1694),
#  ('big', 1662),
#  ('might', 1658),
#  ('interesting', 1648),
#  ('money', 1638),
#  ('us', 1628),
#  ('right', 1625),
#  ('far', 1619),
#  ('quite', 1596),
#  ('without', 1595),
#  ('come', 1595),
#  ('almost', 1574),
#  ('ll', 1567),
#  ('action', 1566),
#  ('awful', 1557),
#  ('kind', 1539),
#  ('reason', 1534),
#  ('am', 1530),
#  ('looks', 1528),
#  ('must', 1522),
#  ('done', 1510),
#  ('comedy', 1504),
#  ('someone', 1490),
#  ('trying', 1486),
#  ('wasn', 1484),
#  ('poor', 1481),
#  ('boring', 1478),
#  ('instead', 1478),
#  ('saw', 1475),
#  ('away', 1469),
#  ('girl', 1463),
#  ('probably', 1444),
#  ('believe', 1434),
#  ('sure', 1433),
#  ('looking', 1430),
#  ('stupid', 1428),
#  ('anyone', 1418),
#  ('times', 1406),
#  ('maybe', 1404),
#  ('world', 1404),
#  ('rather', 1394),
#  ('terrible', 1391),
#  ('may', 1390),
#  ('last', 1390),
#  ('since', 1388),
#  ('let', 1385),
#  ('tv', 1382),
#  ('hard', 1374),
#  ('between', 1374),
#  ('waste', 1358),
#  ('woman', 1356),
#  ('feel', 1354),
#  ('effects', 1348),
#  ('half', 1341),
#  ('own', 1333),
#  ('young', 1317),
#  ('music', 1316),
#  ('idea', 1312),
#  ('sense', 1306),
#  ('bit', 1298),
#  ('having', 1280),
#  ('book', 1278),
#  ('found', 1267),
#  ('put', 1263),
#  ('series', 1263),
#  ('goes', 1256),
#  ('worse', 1249),
#  ('said', 1230),
#  ('comes', 1224),
#  ('role', 1222),
#  ('main', 1220),
#  ('else', 1199),
#  ('everything', 1197),
#  ('yet', 1196),
#  ('low', 1189),
#  ('screen', 1188),
#  ('supposed', 1186),
#  ('actor', 1185),
#  ('either', 1183),
#  ('budget', 1179),
#  ('ending', 1179),
#  ('audience', 1178),
#  ('set', 1177),
#  ('family', 1170),
#  ('left', 1169),
#  ('completely', 1168),
#  ('both', 1158),
#  ('wrong', 1155),
#  ('always', 1151),
#  ('course', 1148),
#  ('place', 1148),
#  ('seem', 1147),
#  ('watched', 1142),
#  ('day', 1132),
#  ('simply', 1130),
#  ('shot', 1126),
#  ('mean', 1117),
#  ('special', 1102),
#  ('dead', 1101),
#  ('three', 1094),
#  ('house', 1085),
#  ('oh', 1084),
#  ('night', 1083),
#  ('read', 1082),
#  ('less', 1067),
#  ('high', 1066),
#  ('year', 1064),
#  ('camera', 1061),
#  ('worth', 1057),
#  ('our', 1056),
#  ('try', 1051),
#  ('horrible', 1046),
#  ('sex', 1046),
#  ('video', 1043),
#  ('black', 1039),
#  ('although', 1036),
#  ('couldn', 1036),
#  ('once', 1033),
#  ('rest', 1022),
#  ('dvd', 1021),
#  ('line', 1018),
#  ('played', 1017),
#  ('fun', 1007),
#  ('during', 1006),
#  ('production', 1003),
#  ('everyone', 1002),
#  ('play', 993),
#  ('mind', 990),
#  ('version', 989),
#  ('kids', 989),
#  ('seeing', 988),
#  ('american', 980),
#  ('given', 978),
#  ('used', 969),
#  ('performance', 968),
#  ('especially', 963),
#  ('together', 963),
#  ('tell', 959),
#  ('women', 958),
#  ('start', 956),
#  ('need', 955),
#  ('second', 953),
#  ('takes', 950),
#  ('each', 950),
#  ('wife', 944),
#  ('dialogue', 942),
#  ('use', 940),
#  ('problem', 938),
#  ('star', 934),
#  ('unfortunately', 931),
#  ('himself', 929),
#  ('doing', 926),
#  ('death', 922),
#  ('name', 921),
#  ('lines', 919),
#  ('killer', 914),
#  ('getting', 913),
#  ('help', 905),
#  ('couple', 902),
#  ('fan', 902),
#  ('head', 898),
#  ('crap', 895),
#  ('guess', 888),
#  ('piece', 884),
#  ('nice', 880),
#  ('different', 878),
#  ('school', 876),
#  ('later', 875),
#  ('entire', 869),
#  ('shows', 860),
#  ('next', 858),
#  ('john', 858),
#  ('short', 857),
#  ('seemed', 857),
#  ('hollywood', 850),
#  ('home', 848),
#  ('true', 846),
#  ('person', 846),
#  ('absolutely', 842),
#  ('sort', 840),
#  ('care', 839),
#  ('understand', 836),
#  ('plays', 835),
#  ('felt', 834),
#  ('written', 829),
#  ('title', 828),
#  ('men', 822),
#  ('until', 821),
#  ('flick', 816),
#  ('decent', 815),
#  ('face', 814),
#  ('friends', 810),
#  ('stars', 807),
#  ('job', 807),
#  ('case', 807),
#  ('itself', 804),
#  ('yes', 801),
#  ('perhaps', 800),
#  ('went', 797),
#  ('wanted', 797),
#  ('called', 796),
#  ('annoying', 795),
#  ('ridiculous', 790),
#  ('tries', 790),
#  ('laugh', 788),
#  ('evil', 787),
#  ('along', 786),
#  ('top', 785),
#  ('hour', 784),
#  ('full', 783),
#  ('came', 780),
#  ('writing', 780),
#  ('keep', 770),
#  ('totally', 767),
#  ('playing', 766),
#  ('god', 765),
#  ('won', 764),
#  ('guys', 763),
#  ('already', 762),
#  ('gore', 757),
#  ('direction', 748),
#  ('save', 746),
#  ('lost', 745),
#  ('example', 744),
#  ('sound', 742),
#  ('war', 741),
#  ('attempt', 735),
#  ('car', 733),
#  ('except', 733),
#  ('moments', 732),
#  ('blood', 732),
#  ('obviously', 730),
#  ('act', 729),
#  ('remember', 728),
#  ('kill', 727),
#  ('truly', 726),
#  ('white', 726),
#  ('father', 726),
#  ('b', 725),
#  ('thinking', 720),
#  ('ok', 716),
#  ('finally', 716),
#  ('turn', 711),
#  ('quality', 701),
#  ('lack', 698),
#  ('style', 694),
#  ('wouldn', 693),
#  ('cheap', 691),
#  ('none', 690),
#  ('kid', 686),
#  ('please', 686),
#  ('boy', 685),
#  ('seriously', 684),
#  ('lead', 680),
#  ('dull', 677),
#  ('children', 676),
#  ('starts', 675),
#  ('stuff', 673),
#  ('hope', 672),
#  ('looked', 670),
#  ('recommend', 669),
#  ('under', 668),
#  ('run', 667),
#  ('killed', 667),
#  ('enjoy', 666),
#  ('others', 666),
#  ('etc', 663),
#  ('myself', 663),
#  ('beginning', 662),
#  ('girls', 662),
#  ('against', 662),
#  ('obvious', 660),
#  ('small', 660),
#  ('hell', 659),
#  ('slow', 657),
#  ('hand', 656),
#  ('wonder', 652),
#  ('lame', 652),
#  ('becomes', 651),
#  ('picture', 651),
#  ('based', 650),
#  ('early', 648),
#  ('behind', 646),
#  ('poorly', 644),
#  ('avoid', 642),
#  ('apparently', 640),
#  ('complete', 640),
#  ('happens', 639),
#  ('anyway', 638),
#  ('classic', 637),
#  ('several', 636),
#  ('despite', 635),
#  ('certainly', 635),
#  ('episode', 635),
#  ('often', 631),
#  ('cut', 630),
#  ('writer', 630),
#  ('mother', 628),
#  ('predictable', 628),
#  ('gave', 628),
#  ('become', 627),
#  ('close', 625),
#  ('fans', 624),
#  ('saying', 621),
#  ('scary', 619),
#  ('stop', 618),
#  ('live', 618),
#  ('wants', 617),
#  ('self', 615),
#  ('mr', 612),
#  ('jokes', 611),
#  ('friend', 611),
#  ('cannot', 610),
#  ('overall', 609),
#  ('cinema', 604),
#  ('child', 603),
#  ('silly', 601),
#  ('beautiful', 596),
#  ('human', 595),
#  ('expect', 594),
#  ('liked', 593),
#  ('happened', 592),
#  ('bunch', 590),
#  ('entertaining', 590),
#  ('actress', 588),
#  ('final', 588),
#  ('says', 584),
#  ('performances', 584),
#  ('turns', 577),
#  ('humor', 577),
#  ('themselves', 576),
#  ('eyes', 576),
#  ('hours', 574),
#  ('happen', 573),
#  ('basically', 572),
#  ('days', 572),
#  ('running', 571),
#  ('involved', 569),
#  ('disappointed', 569),
#  ('call', 569),
#  ('directed', 568),
#  ('group', 568),
#  ('fight', 567),
#  ('daughter', 566),
#  ('talking', 566),
#  ('body', 566),
#  ('badly', 565),
#  ('sorry', 565),
#  ('throughout', 563),
#  ('viewer', 563),
#  ('yourself', 562),
#  ('extremely', 562),
#  ('interest', 561),
#  ('heard', 561),
#  ('violence', 561),
#  ('shots', 559),
#  ('side', 557),
#  ('word', 556),
#  ('art', 555),
#  ('possible', 554),
#  ('dark', 551),
#  ('game', 551),
#  ('hero', 550),
#  ('alone', 549),
#  ('son', 547),
#  ('type', 547),
#  ('leave', 547),
#  ('gives', 546),
#  ('parts', 546),
#  ('single', 546),
#  ('started', 545),
#  ('female', 543),
#  ('rating', 541),
#  ('mess', 541),
#  ('voice', 541),
#  ('aren', 540),
#  ('town', 540),
#  ('drama', 538),
#  ('definitely', 537),
#  ('unless', 536),
#  ('review', 534),
#  ('effort', 533),
#  ('weak', 533),
#  ('able', 533),
#  ('took', 531),
#  ('non', 530),
#  ('five', 530),
#  ('matter', 529),
#  ('usually', 529),
#  ('michael', 528),
#  ('feeling', 526),
#  ('huge', 523),
#  ('sequel', 522),
#  ('soon', 521),
#  ('exactly', 520),
#  ('past', 519),
#  ('turned', 518),
#  ('police', 518),
#  ('tried', 515),
#  ('middle', 513),
#  ('talent', 513),
#  ('genre', 512),
#  ('zombie', 510),
#  ('ends', 509),
#  ('history', 509),
#  ('straight', 503),
#  ('opening', 501),
#  ('serious', 501),
#  ('coming', 501),
#  ('moment', 500),
#  ('lives', 499),
#  ('sad', 499),
#  ('dialog', 498),
#  ('particularly', 498),
#  ('editing', 493),
#  ('clearly', 492),
#  ('beyond', 491),
#  ('earth', 491),
#  ('taken', 490),
#  ('cool', 490),
#  ('level', 489),
#  ('dumb', 489),
#  ('okay', 488),
#  ('major', 487),
#  ('fast', 485),
#  ('premise', 485),
#  ('joke', 484),
#  ('stories', 484),
#  ('wasted', 483),
#  ('minute', 483),
#  ('across', 482),
#  ('mostly', 482),
#  ('rent', 482),
#  ('late', 481),
#  ('falls', 481),
#  ('fails', 481),
#  ('mention', 478),
#  ('theater', 475),
#  ('stay', 472),
#  ('sometimes', 472),
#  ('hit', 468),
#  ('talk', 467),
#  ('fine', 467),
#  ('die', 466),
#  ('storyline', 465),
#  ('pointless', 465),
#  ('taking', 464),
#  ('order', 462),
#  ('brother', 461),
#  ('whatever', 460),
#  ('told', 460),
#  ('wish', 458),
#  ('room', 456),
#  ('career', 455),
#  ('appears', 455),
#  ('write', 455),
#  ('known', 454),
#  ('husband', 454),
#  ('living', 451),
#  ('sit', 450),
#  ('ten', 450),
#  ('words', 449),
#  ('monster', 448),
#  ('chance', 448),
#  ('hate', 444),
#  ('novel', 444),
#  ('add', 443),
#  ('english', 443),
#  ('somehow', 441),
#  ('strange', 440),
#  ('imdb', 438),
#  ('actual', 438),
#  ('total', 437),
#  ('material', 437),
#  ('killing', 437),
#  ('ones', 437),
#  ('knew', 436),
#  ('king', 434),
#  ('number', 434),
#  ('using', 433),
#  ('lee', 431),
#  ('power', 431),
#  ('shown', 431),
#  ('works', 431),
#  ('giving', 431),
#  ('points', 430),
#  ('possibly', 430),
#  ('kept', 430),
#  ('four', 429),
#  ('local', 427),
#  ('usual', 426),
#  ('including', 425),
#  ('problems', 424),
#  ('ago', 424),
#  ('opinion', 424),
#  ('nudity', 423),
#  ('age', 422),
#  ('due', 421),
#  ('roles', 420),
#  ('writers', 419),
#  ('decided', 419),
#  ('near', 418),
#  ('flat', 418),
#  ('easily', 418),
#  ('murder', 417),
#  ('experience', 417),
#  ('reviews', 416),
#  ('imagine', 415),
#  ('feels', 413),
#  ('plain', 411),
#  ('somewhat', 411),
#  ('class', 410),
#  ('score', 410),
#  ('song', 409),
#  ('bring', 409),
#  ('whether', 409),
#  ('otherwise', 408),
#  ('whose', 408),
#  ('average', 408),
#  ('pathetic', 407),
#  ('nearly', 407),
#  ('knows', 407),
#  ('zombies', 407),
#  ('cinematography', 406),
#  ('cheesy', 406),
#  ('upon', 406),
#  ('city', 405),
#  ('space', 405),
#  ('credits', 404),
#  ('james', 403),
#  ('lots', 403),
#  ('change', 403),
#  ('entertainment', 402),
#  ('nor', 402),
#  ('wait', 401),
#  ('released', 400),
#  ('needs', 399),
#  ('shame', 398),
#  ('attention', 396),
#  ('comments', 394),
#  ('bored', 393),
#  ('free', 393),
#  ('lady', 393),
#  ('expected', 392),
#  ('needed', 392),
#  ('clear', 392),
#  ('view', 391),
#  ('development', 390),
#  ('check', 390),
#  ('doubt', 390),
#  ('figure', 389),
#  ('mystery', 389),
#  ('excellent', 388),
#  ('garbage', 388),
#  ('sequence', 386),
#  ('television', 386),
#  ('o', 385),
#  ('sets', 385),
#  ('laughable', 384),
#  ('potential', 384),
#  ('robert', 382),
#  ('light', 382),
#  ('country', 382),
#  ('documentary', 382),
#  ('reality', 382),
#  ('general', 381),
#  ('ask', 381),
#  ('comic', 380),
#  ('fall', 380),
#  ('begin', 380),
#  ('footage', 379),
#  ('stand', 379),
#  ('forced', 379),
#  ('trash', 379),
#  ('remake', 379),
#  ('thriller', 378),
#  ('songs', 378),
#  ('gay', 377),
#  ('within', 377),
#  ('hardly', 376),
#  ('above', 375),
#  ('gone', 375),
#  ('george', 374),
#  ('means', 373),
#  ('sounds', 373),
#  ('directing', 372),
#  ('move', 372),
#  ('david', 372),
#  ('buy', 372),
#  ('rock', 371),
#  ('forward', 371),
#  ('important', 371),
#  ('hot', 370),
#  ('haven', 370),
#  ('filmed', 370),
#  ('british', 370),
#  ('heart', 369),
#  ('reading', 369),
#  ('fake', 369),
#  ('incredibly', 368),
#  ('weird', 368),
#  ('hear', 368),
#  ('enjoyed', 367),
#  ('hilarious', 367),
#  ('cop', 367),
#  ('musical', 367),
#  ('message', 366),
#  ('happy', 366),
#  ('pay', 366),
#  ('laughs', 365),
#  ('box', 365),
#  ('suspense', 363),
#  ('sadly', 363),
#  ('eye', 362),
#  ('third', 361),
#  ('similar', 361),
#  ('named', 361),
#  ('modern', 360),
#  ('failed', 359),
#  ('events', 359),
#  ('forget', 358),
#  ('question', 358),
#  ('male', 357),
#  ('finds', 357),
#  ('perfect', 356),
#  ('spent', 355),
#  ('sister', 355),
#  ('feature', 354),
#  ('result', 354),
#  ('comment', 353),
#  ('girlfriend', 353),
#  ('sexual', 352),
#  ('attempts', 351),
#  ('neither', 351),
#  ('richard', 351),
#  ('screenplay', 350),
#  ('elements', 350),
#  ('spoilers', 349),
#  ('brain', 348),
#  ('filmmakers', 348),
#  ('showing', 348),
#  ('miss', 347),
#  ('dr', 347),
#  ('christmas', 347),
#  ('cover', 345),
#  ('red', 344),
#  ('sequences', 344),
#  ('typical', 343),
#  ('excuse', 343),
#  ('crazy', 342),
#  ('ideas', 342),
#  ('baby', 342),
#  ('loved', 341),
#  ('meant', 341),
#  ('worked', 340),
#  ('fire', 340),
#  ('unbelievable', 339),
#  ('follow', 339),
#  ('theme', 337),
#  ('barely', 336),
#  ('producers', 336),
#  ('twist', 336),
#  ('plus', 336),
#  ('appear', 336),
#  ('directors', 335),
#  ('team', 335),
#  ('viewers', 333),
#  ('leads', 332),
#  ('tom', 332),
#  ('slasher', 332),
#  ('wrote', 331),
#  ('villain', 331),
#  ('gun', 331),
#  ('working', 331),
#  ('island', 330),
#  ('strong', 330),
#  ('open', 330),
#  ('realize', 330),
#  ('positive', 329),
#  ('disappointing', 329),
#  ('yeah', 329),
#  ('quickly', 329),
#  ('weren', 328),
#  ('release', 328),
#  ('simple', 328),
#  ('honestly', 328),
#  ('eventually', 327),
#  ('period', 327),
#  ('tells', 327),
#  ('kills', 327),
#  ('doctor', 327),
#  ('nowhere', 326),
#  ('list', 326),
#  ('acted', 326),
#  ('herself', 326),
#  ('dog', 326),
#  ('walk', 325),
#  ('air', 324),
#  ('apart', 324),
#  ('makers', 323),
#  ('subject', 323),
#  ('learn', 322),
#  ('fi', 322),
#  ('sci', 319),
#  ('bother', 319),
#  ('admit', 319),
#  ('jack', 318),
#  ('disappointment', 318),
#  ('hands', 318),
#  ('note', 318),
#  ('certain', 317),
#  ('e', 317),
#  ('value', 317),
#  ('casting', 317),
#  ('grade', 316),
#  ('peter', 316),
#  ('suddenly', 315),
#  ('missing', 315),
#  ('form', 313),
#  ('stick', 313),
#  ('previous', 313),
#  ('break', 313),
#  ('soundtrack', 312),
#  ('surprised', 311),
#  ('front', 311),
#  ('expecting', 311),
#  ('parents', 310),
#  ('surprise', 310),
#  ('relationship', 310),
#  ('shoot', 309),
#  ('today', 309),
#  ('painful', 308),
#  ('ways', 308),
#  ('leaves', 308),
#  ('ended', 308),
#  ('creepy', 308),
#  ('concept', 308),
#  ('somewhere', 308),
#  ('vampire', 308),
#  ('spend', 307),
#  ('th', 307),
#  ('future', 306),
#  ('difficult', 306),
#  ('effect', 306),
#  ('fighting', 306),
#  ('street', 306),
#  ('c', 305),
#  ('america', 305),
#  ('accent', 304),
#  ('truth', 302),
#  ('project', 302),
#  ('joe', 301),
#  ('f', 301),
#  ('deal', 301),
#  ('indeed', 301),
#  ('biggest', 300),
#  ('rate', 300),
#  ('paul', 299),
#  ('japanese', 299),
#  ('utterly', 298),
#  ('begins', 298),
#  ('redeeming', 298),
#  ('college', 298),
#  ('york', 297),
#  ('fairly', 297),
#  ('disney', 297),
#  ('crew', 296),
#  ('create', 296),
#  ('cartoon', 296),
#  ('revenge', 296),
#  ('co', 295),
#  ('outside', 295),
#  ('computer', 295),
#  ('interested', 295),
#  ('stage', 295),
#  ('considering', 294),
#  ('speak', 294),
#  ('among', 294),
#  ('towards', 293),
#  ('channel', 293),
#  ('sick', 293),
#  ('talented', 292),
#  ('cause', 292),
#  ('particular', 292),
#  ('van', 292),
#  ('hair', 292),
#  ('bottom', 291),
#  ('reasons', 291),
#  ('mediocre', 290),
#  ('cat', 290),
#  ('telling', 290),
#  ('supporting', 289),
#  ('store', 289),
#  ('hoping', 288),
#  ('waiting', 288),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times
for word, count in list(total_counts.most_common()):
    if(count>10):
        pos_neg_ratios[word] = positive_counts[word]/float(negative_counts[word]+1)

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0607993145235326
# Pos-to-neg ratio for 'amazing' = 4.022813688212928
# Pos-to-neg ratio for 'terrible' = 0.17744252873563218

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the postive-to-negative rations of very postive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value from neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
# we use log here because 
for word, ratio in pos_neg_ratios.most_common():
    if (ratio>1):
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = -np.log((1/(ratio+0.01)))

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902269426102881
# Pos-to-neg ratio for 'amazing' = 1.3919815802404802
# Pos-to-neg ratio for 'terrible' = -1.6742829939664696

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()[-10:]
# Out:
# [('slipstream', -4.6051701859880918),
#  ('redline', -4.6051701859880918),
#  ('qi', -4.6051701859880918),
#  ('summersisle', -4.6051701859880918),
#  ('sagemiller', -4.6051701859880918),
#  ('swinton', -4.6051701859880918),
#  ('borel', -4.6051701859880918),
#  ('manu', -4.6051701859880918),
#  ('frewer', -4.6051701859880918),
#  ('rosarios', -4.6051701859880918)]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('rosarios', -4.6051701859880918),
#  ('frewer', -4.6051701859880918),
#  ('manu', -4.6051701859880918),
#  ('borel', -4.6051701859880918),
#  ('swinton', -4.6051701859880918),
#  ('sagemiller', -4.6051701859880918),
#  ('summersisle', -4.6051701859880918),
#  ('qi', -4.6051701859880918),
#  ('redline', -4.6051701859880918),
#  ('slipstream', -4.6051701859880918),
#  ('bolo', -4.6051701859880918),
#  ('emraan', -4.6051701859880918),
#  ('geico', -4.6051701859880918),
#  ('cato', -4.6051701859880918),
#  ('liliom', -4.6051701859880918),
#  ('rajni', -4.6051701859880918),
#  ('mayeda', -4.6051701859880918),
#  ('crapfest', -4.6051701859880918),
#  ('tmtm', -4.6051701859880918),
#  ('sued', -4.6051701859880918),
#  ('keyes', -4.6051701859880918),
#  ('nichole', -4.6051701859880918),
#  ('straightheads', -4.6051701859880918),
#  ('aluminium', -4.6051701859880918),
#  ('groaning', -4.6051701859880918),
#  ('templars', -4.6051701859880918),
#  ('krista', -4.6051701859880918),
#  ('spandex', -4.6051701859880918),
#  ('unisols', -4.6051701859880918),
#  ('mache', -4.6051701859880918)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set(total_counts.keys())

# %%
vocab
# Out:
# {'',
#  'fuelled',
#  'commendations',
#  'hackenstien',
#  'lethargically',
#  'clearances',
#  'diahnn',
#  'steptoe',
#  'weebl',
#  'merriest',
#  'jodha',
#  'slobby',
#  'retreat',
#  'horizons',
#  'scribbling',
#  'daisy',
#  'spadafore',
#  'deniro',
#  'aquarium',
#  'invests',
#  'barcelona',
#  'kola',
#  'masked',
#  'parking',
#  'doink',
#  'boobtube',
#  'rebath',
#  'tonne',
#  'cinemaa',
#  'showgirl',
#  'germane',
#  'vaulted',
#  'monsta',
#  'renji',
#  'fleer',
#  'doused',
#  'yellowing',
#  'computer',
#  'lize',
#  'abusing',
#  'tomason',
#  'supervision',
#  'meiks',
#  'nutso',
#  'paperclip',
#  'peregrinations',
#  'kept',
#  'bmws',
#  'steeped',
#  'salary',
#  'study',
#  'cassella',
#  'controlling',
#  'misnomered',
#  'demagogic',
#  'psychokinetic',
#  'barber',
#  'roughhousing',
#  'rattlesnake',
#  'secure',
#  'financier',
#  'adaptor',
#  'preformed',
#  'wiley',
#  'blackploitation',
#  'featuresthat',
#  'richthofen',
#  'anja',
#  'mercifully',
#  'endnote',
#  'narrators',
#  'lange',
#  'multitasking',
#  'zappati',
#  'headlock',
#  'henze',
#  'bankability',
#  'irvine',
#  'apres',
#  'inventors',
#  'decorum',
#  'pus',
#  'abbot',
#  'metacinematic',
#  'jie',
#  'spiret',
#  'macross',
#  'bergeron',
#  'jarndyce',
#  'titledunsolved',
#  'stealling',
#  'giblets',
#  'sarcastically',
#  'chiefton',
#  'hearen',
#  'antoine',
#  'historically',
#  'sublimated',
#  'sensous',
#  'lerche',
#  'meaningfull',
#  'lemoine',
#  'negras',
#  'mae',
#  'nekromantiks',
#  'scummiest',
#  'exasperates',
#  'khans',
#  'unbroken',
#  'eduardo',
#  'mercury',
#  'sellers',
#  'fatale',
#  'seeping',
#  'munchausen',
#  'maximillian',
#  'refered',
#  'vetted',
#  'castigated',
#  'gumshoes',
#  'deker',
#  'lease',
#  'wagoneer',
#  'katia',
#  'bete',
#  'darabont',
#  'norwegia',
#  'pov',
#  'ognianova',
#  'bizarro',
#  'uprightness',
#  'anesthesiologists',
#  'atem',
#  'foursome',
#  'scholars',
#  'rajshree',
#  'paupers',
#  'endingin',
#  'pronounces',
#  'mejding',
#  'subnormal',
#  'ninety',
#  'implicating',
#  'rebellious',
#  'heckler',
#  'foiling',
#  'acedemy',
#  'townies',
#  'svale',
#  'cert',
#  'overs',
#  'securing',
#  'stormer',
#  'cigar',
#  'rudd',
#  'sinisterness',
#  'dress',
#  'misfitted',
#  'damita',
#  'normals',
#  'zy',
#  'synching',
#  'unshakably',
#  'same',
#  'thereafter',
#  'shiraki',
#  'infamously',
#  'cg',
#  'committal',
#  'pharmaceutical',
#  'manqu',
#  'hoods',
#  'argyle',
#  'mirren',
#  'frustrates',
#  'whig',
#  'hypnosis',
#  'portico',
#  'caricaturish',
#  'portugeuse',
#  'dont',
#  'blather',
#  'extreamly',
#  'inferiors',
#  'cheorgraphed',
#  'glitzy',
#  'fardeen',
#  'louvred',
#  'resonated',
#  'esthetics',
#  'uhhh',
#  'elsons',
#  'uggghh',
#  'uphold',
#  'maidens',
#  'sentimentalize',
#  'syllabus',
#  'yvette',
#  'replacement',
#  'lamm',
#  'michelangelo',
#  'overboard',
#  'odete',
#  'sorting',
#  'tindle',
#  'communism',
#  'target',
#  'arbor',
#  'sloper',
#  'isareli',
#  'echo',
#  'schygulla',
#  'prospering',
#  'trucks',
#  'sits',
#  'colourful',
#  'spoilt',
#  'szubanski',
#  'acronym',
#  'aspen',
#  'sharers',
#  'carping',
#  'mishkin',
#  'wong',
#  'fartsys',
#  'scrounge',
#  'jorma',
#  'manhating',
#  'arminass',
#  'dilwale',
#  'dunes',
#  'communicate',
#  'kph',
#  'beetle',
#  'kern',
#  'bookstore',
#  'automaker',
#  'affront',
#  'tapping',
#  'auditorium',
#  'autobiographic',
#  'unease',
#  'wardrobe',
#  'goodness',
#  'steinmann',
#  'henleys',
#  'skidoo',
#  'weel',
#  'thialnd',
#  'bilateral',
#  'thebom',
#  'neighbouring',
#  'reed',
#  'abril',
#  'edtv',
#  'kinematograph',
#  'manat',
#  'careys',
#  'gunfire',
#  'relative',
#  'cattivi',
#  'corresponded',
#  'nickleby',
#  'dyanne',
#  'ferment',
#  'caption',
#  'tudors',
#  'knowingly',
#  'learner',
#  'duddy',
#  'nugent',
#  'unpalatably',
#  'hardesty',
#  'marenghi',
#  'campaigns',
#  'winifred',
#  'ebeneezer',
#  'unignorable',
#  'ands',
#  'plotkurt',
#  'sneakiness',
#  'grave',
#  'comic',
#  'conservativism',
#  'galleys',
#  'fetishistic',
#  'pleases',
#  'affinity',
#  'hynde',
#  'discontented',
#  'suffer',
#  'importance',
#  'regan',
#  'rebe',
#  'saat',
#  'showing',
#  'psychotically',
#  'sthf',
#  'possesing',
#  'footloose',
#  'intimidation',
#  'topped',
#  'electrocuting',
#  'tsk',
#  'chilled',
#  'huang',
#  'meteoric',
#  'callus',
#  'potently',
#  'candians',
#  'mediaeval',
#  'matchup',
#  'elicited',
#  'buford',
#  'shipmate',
#  'hyller',
#  'rearveiw',
#  'overreacting',
#  'lockyer',
#  'months',
#  'honk',
#  'pushes',
#  'unstated',
#  'bondi',
#  'mnniskor',
#  'modestly',
#  'johannes',
#  'moving',
#  'whodunit',
#  'ranges',
#  'confetti',
#  'melted',
#  'crystallized',
#  'mary',
#  'hopkins',
#  'wildcats',
#  'sobriety',
#  'decorating',
#  'aspiration',
#  'sensuously',
#  'duroy',
#  'takeshi',
#  'careering',
#  'rejoiced',
#  'amy',
#  'lolita',
#  'kayo',
#  'paleontologist',
#  'rounds',
#  'sexes',
#  'squeeze',
#  'sicken',
#  'bauble',
#  'bodys',
#  'chasey',
#  'armor',
#  'saucy',
#  'bloss',
#  'backwards',
#  'reveal',
#  'rural',
#  'emerging',
#  'cortland',
#  'participated',
#  'triana',
#  'lived',
#  'anymore',
#  'wouldn',
#  'poop',
#  'revoked',
#  'gwenneth',
#  'aaliyah',
#  'ilk',
#  'fruitcake',
#  'mexicans',
#  'associate',
#  'mellow',
#  'expel',
#  'accede',
#  'fluctuating',
#  'lenghth',
#  'prejudiced',
#  'walder',
#  'billboards',
#  'appreciation',
#  'ruthless',
#  'comin',
#  'classist',
#  'ozon',
#  'squadroom',
#  'ablaze',
#  'bensonhurst',
#  'disadvantageous',
#  'idiomatic',
#  'stretched',
#  'stuyvesant',
#  'prizzi',
#  'gelded',
#  'huber',
#  'travelogue',
#  'despised',
#  'toplining',
#  'pensacolians',
#  'gleaming',
#  'athol',
#  'armpits',
#  'bally',
#  'saxophonists',
#  'sniffed',
#  'scandanavian',
#  'ordained',
#  'faiths',
#  'garrett',
#  'fannie',
#  'incidentally',
#  'akelly',
#  'class',
#  'yaks',
#  'awkward',
#  'supersoldier',
#  'tolkiens',
#  'sharikovs',
#  'exurbia',
#  'mouldy',
#  'guys',
#  'sahsa',
#  'baffled',
#  'saskatoon',
#  'occurred',
#  'juan',
#  'hauser',
#  'jewel',
#  'airforce',
#  'overbroad',
#  'offsets',
#  'granddaughter',
#  'stuningly',
#  'heading',
#  'sphere',
#  'buddist',
#  'dread',
#  'silverlake',
#  'dispassionately',
#  'doodle',
#  'arriv',
#  'hanfstaengel',
#  'jardyce',
#  'splattered',
#  'pirouettes',
#  'islanders',
#  'gogh',
#  'regalia',
#  'hunted',
#  'resorts',
#  'jan',
#  'bloodsucking',
#  'societal',
#  'meandered',
#  'confidentiality',
#  'tenancier',
#  'ykai',
#  'alissia',
#  'meta',
#  'jalousie',
#  'sniffish',
#  'hairdo',
#  'farm',
#  'jett',
#  'malfatti',
#  'veddar',
#  'asteroids',
#  'durbin',
#  'sacramento',
#  'termite',
#  'stockton',
#  'incompetence',
#  'pe',
#  'yau',
#  'loggerheads',
#  'dawson',
#  'cabo',
#  'trongard',
#  'zelniker',
#  'womanhood',
#  'nobles',
#  'dissectionist',
#  'wuornos',
#  'calibre',
#  'macarther',
#  'slightest',
#  'loa',
#  'copain',
#  'imps',
#  'punchline',
#  'subsist',
#  'batistabomb',
#  'foe',
#  'ruminations',
#  'dimestore',
#  'charistmatic',
#  'identifies',
#  'parc',
#  'persona',
#  'wathced',
#  'fisheris',
#  'descendents',
#  'supplier',
#  'belmondo',
#  'gojoe',
#  'beneficence',
#  'aiken',
#  'helo',
#  'regent',
#  'millers',
#  'tootsie',
#  'lightheartedness',
#  'sendback',
#  'tapes',
#  'foxworthy',
#  'maximally',
#  'whiny',
#  'samaritan',
#  'astronaut',
#  'overwatched',
#  'unforgivably',
#  'pyramid',
#  'nepalese',
#  'bunk',
#  'misjudging',
#  'recordings',
#  'lense',
#  'dixie',
#  'mirkovich',
#  'silos',
#  'chattering',
#  'rodder',
#  'logline',
#  'trekking',
#  'jing',
#  'intimacies',
#  'conditions',
#  'simmers',
#  'tori',
#  'psychologist',
#  'anklet',
#  'chomiak',
#  'convergent',
#  'nekromantik',
#  'tisa',
#  'rosenliski',
#  'unanimousness',
#  'unintenional',
#  'protags',
#  'contre',
#  'replete',
#  'brims',
#  'footpath',
#  'dozen',
#  'bingo',
#  'bubbling',
#  'ezra',
#  'montage',
#  'seppuka',
#  'lumiere',
#  'unwaveringly',
#  'crapfest',
#  'andr',
#  'strutts',
#  'vitametavegamin',
#  'palestijn',
#  'thuggees',
#  'orginality',
#  'jellyfish',
#  'lettich',
#  'propagandic',
#  'medalist',
#  'purchased',
#  'mcmanus',
#  'bestiality',
#  'evre',
#  'winos',
#  'criticised',
#  'capiche',
#  'workload',
#  'venting',
#  'arquette',
#  'nerds',
#  'coquette',
#  'overseas',
#  'grays',
#  'excitingly',
#  'bodice',
#  'ravelling',
#  'horler',
#  'druten',
#  'woohoo',
#  'multistarrer',
#  'inn',
#  'catalogues',
#  'trimble',
#  'washrooms',
#  'jain',
#  'hetrakul',
#  'biochemical',
#  'accordian',
#  'bergman',
#  'wizardry',
#  'zed',
#  'congo',
#  'medicinal',
#  'brrr',
#  'moskve',
#  'prefigures',
#  'concert',
#  'menotti',
#  'lousiness',
#  'elmer',
#  'dutt',
#  'looniness',
#  'turiqistan',
#  'eliott',
#  'hiking',
#  'bomba',
#  'banishses',
#  'lene',
#  'varies',
#  'idiota',
#  'lawton',
#  'reissue',
#  'princesse',
#  'abhay',
#  'underlying',
#  'worth',
#  'glo',
#  'frannie',
#  'pekinpah',
#  'caligary',
#  'ferzetti',
#  'problem',
#  'prosecutors',
#  'bover',
#  'bladck',
#  'cloris',
#  'confusions',
#  'week',
#  'unredeemable',
#  'misunderstand',
#  'rediscovering',
#  'stew',
#  'mastroianni',
#  'phlegm',
#  'wouldhave',
#  'leterrier',
#  'coulisses',
#  'dummheit',
#  'prescience',
#  'happening',
#  'santimoniousness',
#  'reason',
#  'hillermans',
#  'thousand',
#  'taints',
#  'jcpenney',
#  'uecker',
#  'puppetry',
#  'sexploitative',
#  'reddin',
#  'tainted',
#  'popsicles',
#  'leagues',
#  'lindsay',
#  'minogue',
#  'natal',
#  'trots',
#  'gratuitously',
#  'lutte',
#  'breats',
#  'discerned',
#  'torme',
#  'safari',
#  'chevalia',
#  'coincidently',
#  'dyno',
#  'stepmotherhood',
#  'peddler',
#  'tbu',
#  'proven',
#  'iago',
#  'detractions',
#  'stalwarts',
#  'reclamation',
#  'heidecke',
#  'reunion',
#  'insulate',
#  'kanno',
#  'piquantly',
#  'beens',
#  'adhesive',
#  'leclerc',
#  'hoshi',
#  'eck',
#  'comparrison',
#  'troublesome',
#  'reflected',
#  'gw',
#  'gfx',
#  'thoroughly',
#  'fragglerock',
#  'slats',
#  'influencee',
#  'thunderstorms',
#  'magalhes',
#  'haber',
#  'rouncewell',
#  'tpb',
#  'pianos',
#  'fenn',
#  'detecting',
#  'wrrrooonnnnggg',
#  'shareholders',
#  'fanbase',
#  'overdramatic',
#  'bastketball',
#  'indefinite',
#  'advanced',
#  'adela',
#  'actorsthey',
#  'autopsies',
#  'renovations',
#  'mahayana',
#  'prescribe',
#  'bandstand',
#  'sexy',
#  'becoming',
#  'pork',
#  'elson',
#  'sharifi',
#  'centre',
#  'earls',
#  'pelts',
#  'haralambopoulos',
#  'shootem',
#  'glamouresque',
#  'trinary',
#  'budget',
#  'explain',
#  'mooching',
#  'falsies',
#  'costarred',
#  'catalogued',
#  'infestation',
#  'najimi',
#  'speedball',
#  'jetliner',
#  'trifles',
#  'desi',
#  'blazer',
#  'fathering',
#  'pixar',
#  'detritus',
#  'burying',
#  'remedy',
#  'dispite',
#  'greatest',
#  'ripping',
#  'adjusted',
#  'yada',
#  'ditsy',
#  'overabundance',
#  'burping',
#  'straddled',
#  'eventide',
#  'firmament',
#  'dtr',
#  'glom',
#  'formosa',
#  'stupifying',
#  'taing',
#  'capomezza',
#  'monaca',
#  'copies',
#  'chelita',
#  'amrican',
#  'ellison',
#  'paiyan',
#  'floating',
#  'entrapment',
#  'diapered',
#  'darden',
#  'slvia',
#  'flatulence',
#  'cancellation',
#  'glaucoma',
#  'freaky',
#  'hammond',
#  'percy',
#  'whimper',
#  'saltwater',
#  'mallaig',
#  'anschel',
#  'nondescript',
#  'ingeniously',
#  'filmographers',
#  'sternwood',
#  'unharmed',
#  'unread',
#  'witherspoon',
#  'rewriting',
#  'bannon',
#  'gratuitious',
#  'milkman',
#  'pending',
#  'reissued',
#  'legitimacy',
#  'architects',
#  'marit',
#  'flippin',
#  'spliff',
#  'nozawa',
#  'culled',
#  'smita',
#  'tofu',
#  'bailsman',
#  'premonitions',
#  'paracetamol',
#  'gallows',
#  'elk',
#  'woods',
#  'passage',
#  'conclude',
#  'segways',
#  'braggart',
#  'fanu',
#  'low',
#  'hastens',
#  'altitude',
#  'wage',
#  'officially',
#  'crescendoing',
#  'marine',
#  'meltdown',
#  'wincott',
#  'nymphomania',
#  'crucifies',
#  'oke',
#  'franclisco',
#  'muffat',
#  'lockers',
#  'paraphrase',
#  'inconspicuous',
#  'snob',
#  'dawg',
#  'drunkeness',
#  'collusion',
#  'chalant',
#  'bugle',
#  'excel',
#  'moors',
#  'elitist',
#  'griping',
#  'aria',
#  'thingee',
#  'confident',
#  'manfully',
#  'insturmental',
#  'teletubbies',
#  'movements',
#  'ific',
#  'confound',
#  'hoses',
#  'tt',
#  'silverstein',
#  'trashy',
#  'according',
#  'wait',
#  'heartland',
#  'sirico',
#  'donatello',
#  'jeongg',
#  'interpreted',
#  'bootlegging',
#  'drosselmeyer',
#  'dismissal',
#  'wished',
#  'dareus',
#  'suhaag',
#  'klutz',
#  'bridget',
#  'weww',
#  'favorit',
#  'igniminiously',
#  'entwines',
#  'tana',
#  'imc',
#  'whalin',
#  'noughties',
#  'sumpin',
#  'boooooooo',
#  'harming',
#  'pace',
#  'collections',
#  'cource',
#  'dependence',
#  'aspired',
#  'spoilerish',
#  'unexploded',
#  'utrillo',
#  'toyomichi',
#  'position',
#  'gentlemanly',
#  'treason',
#  'thinly',
#  'deckchair',
#  'temuco',
#  'filmographies',
#  'governmentally',
#  'gujerati',
#  'scouting',
#  'lenders',
#  'goldsman',
#  'romp',
#  'tricia',
#  'ringo',
#  'nincompoops',
#  'sierras',
#  'okinawan',
#  'amine',
#  'somesuch',
#  'viscous',
#  'brooklyners',
#  'sceneries',
#  'jasonx',
#  'taciturn',
#  'bulette',
#  'shooting',
#  'harlow',
#  'gaye',
#  'affirms',
#  'intricacies',
#  'saran',
#  'loopy',
#  'simba',
#  'sofa',
#  'capitalists',
#  'densely',
#  'enigmas',
#  'annoyingly',
#  'muppeteers',
#  'audrina',
#  'psicoanalitical',
#  'purge',
#  'hooves',
#  'rottens',
#  'conquerors',
#  'fortnight',
#  'amatuer',
#  'leger',
#  'haye',
#  'jeaneane',
#  'hogan',
#  'elase',
#  'exhibited',
#  'molesting',
#  'repulse',
#  'prevails',
#  'progressed',
#  'marginalizes',
#  'expressionless',
#  'chaeles',
#  'aladdin',
#  'britton',
#  'completer',
#  'postlesumthingor',
#  'va',
#  'paperback',
#  'unbelievability',
#  'soninha',
#  'droppingly',
#  'sexa',
#  'sharif',
#  'mechanics',
#  'prodigiously',
#  'natalie',
#  'completes',
#  'heady',
#  'bunkum',
#  'sweating',
#  'autobiograhical',
#  'excessive',
#  'forefather',
#  'ironhead',
#  'underpants',
#  'fastforward',
#  'faschist',
#  'camp',
#  'toasts',
#  'ronni',
#  'direstion',
#  'deletion',
#  'envying',
#  ...}

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros(shape=(1, vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'fuelled': 1,
#  'commendations': 2,
#  'hackenstien': 3,
#  'lethargically': 4,
#  'clearances': 5,
#  'diahnn': 6,
#  'steptoe': 7,
#  'weebl': 8,
#  'merriest': 9,
#  'jodha': 10,
#  'slobby': 11,
#  'retreat': 12,
#  'horizons': 13,
#  'scribbling': 14,
#  'daisy': 15,
#  'spadafore': 16,
#  'deniro': 17,
#  'aquarium': 18,
#  'invests': 19,
#  'barcelona': 20,
#  'kola': 21,
#  'masked': 22,
#  'parking': 23,
#  'doink': 24,
#  'boobtube': 25,
#  'rebath': 26,
#  'tonne': 27,
#  'cinemaa': 28,
#  'showgirl': 29,
#  'germane': 30,
#  'vaulted': 31,
#  'monsta': 32,
#  'renji': 33,
#  'fleer': 34,
#  'doused': 35,
#  'yellowing': 36,
#  'computer': 37,
#  'lize': 38,
#  'abusing': 39,
#  'tomason': 40,
#  'supervision': 41,
#  'meiks': 42,
#  'nutso': 43,
#  'paperclip': 44,
#  'peregrinations': 45,
#  'kept': 46,
#  'bmws': 47,
#  'steeped': 48,
#  'salary': 49,
#  'study': 50,
#  'cassella': 51,
#  'controlling': 52,
#  'misnomered': 53,
#  'demagogic': 54,
#  'psychokinetic': 55,
#  'barber': 56,
#  'roughhousing': 57,
#  'rattlesnake': 58,
#  'secure': 59,
#  'financier': 60,
#  'adaptor': 61,
#  'preformed': 62,
#  'wiley': 63,
#  'blackploitation': 64,
#  'featuresthat': 65,
#  'richthofen': 66,
#  'anja': 67,
#  'mercifully': 68,
#  'endnote': 69,
#  'narrators': 70,
#  'lange': 71,
#  'multitasking': 72,
#  'zappati': 73,
#  'headlock': 74,
#  'henze': 75,
#  'bankability': 76,
#  'irvine': 77,
#  'apres': 78,
#  'inventors': 79,
#  'decorum': 80,
#  'pus': 81,
#  'abbot': 82,
#  'metacinematic': 83,
#  'jie': 84,
#  'spiret': 85,
#  'macross': 86,
#  'bergeron': 87,
#  'jarndyce': 88,
#  'titledunsolved': 89,
#  'stealling': 90,
#  'giblets': 91,
#  'sarcastically': 92,
#  'chiefton': 93,
#  'hearen': 94,
#  'antoine': 95,
#  'historically': 96,
#  'sublimated': 97,
#  'sensous': 98,
#  'lerche': 99,
#  'meaningfull': 100,
#  'lemoine': 101,
#  'negras': 102,
#  'mae': 103,
#  'nekromantiks': 104,
#  'scummiest': 105,
#  'exasperates': 106,
#  'khans': 107,
#  'unbroken': 108,
#  'eduardo': 109,
#  'mercury': 110,
#  'sellers': 111,
#  'fatale': 112,
#  'seeping': 113,
#  'munchausen': 114,
#  'maximillian': 115,
#  'refered': 116,
#  'vetted': 117,
#  'castigated': 118,
#  'gumshoes': 119,
#  'deker': 120,
#  'lease': 121,
#  'wagoneer': 122,
#  'katia': 123,
#  'bete': 124,
#  'darabont': 125,
#  'norwegia': 126,
#  'pov': 127,
#  'ognianova': 128,
#  'bizarro': 129,
#  'uprightness': 130,
#  'anesthesiologists': 131,
#  'atem': 132,
#  'foursome': 133,
#  'scholars': 134,
#  'rajshree': 135,
#  'paupers': 136,
#  'endingin': 137,
#  'pronounces': 138,
#  'mejding': 139,
#  'subnormal': 140,
#  'ninety': 141,
#  'implicating': 142,
#  'rebellious': 143,
#  'heckler': 144,
#  'foiling': 145,
#  'acedemy': 146,
#  'townies': 147,
#  'svale': 148,
#  'cert': 149,
#  'overs': 150,
#  'securing': 151,
#  'stormer': 152,
#  'cigar': 153,
#  'rudd': 154,
#  'sinisterness': 155,
#  'dress': 156,
#  'misfitted': 157,
#  'damita': 158,
#  'normals': 159,
#  'zy': 160,
#  'synching': 161,
#  'unshakably': 162,
#  'same': 163,
#  'thereafter': 164,
#  'shiraki': 165,
#  'infamously': 166,
#  'cg': 167,
#  'committal': 168,
#  'pharmaceutical': 169,
#  'manqu': 170,
#  'hoods': 171,
#  'argyle': 172,
#  'mirren': 173,
#  'frustrates': 174,
#  'whig': 175,
#  'hypnosis': 176,
#  'portico': 177,
#  'caricaturish': 178,
#  'portugeuse': 179,
#  'dont': 180,
#  'blather': 181,
#  'extreamly': 182,
#  'inferiors': 183,
#  'cheorgraphed': 184,
#  'glitzy': 185,
#  'fardeen': 186,
#  'louvred': 187,
#  'resonated': 188,
#  'esthetics': 189,
#  'uhhh': 190,
#  'elsons': 191,
#  'uggghh': 192,
#  'uphold': 193,
#  'maidens': 194,
#  'sentimentalize': 195,
#  'syllabus': 196,
#  'yvette': 197,
#  'replacement': 198,
#  'lamm': 199,
#  'michelangelo': 200,
#  'overboard': 201,
#  'odete': 202,
#  'sorting': 203,
#  'tindle': 204,
#  'communism': 205,
#  'target': 206,
#  'arbor': 207,
#  'sloper': 208,
#  'isareli': 209,
#  'echo': 210,
#  'schygulla': 211,
#  'prospering': 212,
#  'trucks': 213,
#  'sits': 214,
#  'colourful': 215,
#  'spoilt': 216,
#  'szubanski': 217,
#  'acronym': 218,
#  'aspen': 219,
#  'sharers': 220,
#  'carping': 221,
#  'mishkin': 222,
#  'wong': 223,
#  'fartsys': 224,
#  'scrounge': 225,
#  'jorma': 226,
#  'manhating': 227,
#  'arminass': 228,
#  'dilwale': 229,
#  'dunes': 230,
#  'communicate': 231,
#  'kph': 232,
#  'beetle': 233,
#  'kern': 234,
#  'bookstore': 235,
#  'automaker': 236,
#  'affront': 237,
#  'tapping': 238,
#  'auditorium': 239,
#  'autobiographic': 240,
#  'unease': 241,
#  'wardrobe': 242,
#  'goodness': 243,
#  'steinmann': 244,
#  'henleys': 245,
#  'skidoo': 246,
#  'weel': 247,
#  'thialnd': 248,
#  'bilateral': 249,
#  'thebom': 250,
#  'neighbouring': 251,
#  'reed': 252,
#  'abril': 253,
#  'edtv': 254,
#  'kinematograph': 255,
#  'manat': 256,
#  'careys': 257,
#  'gunfire': 258,
#  'relative': 259,
#  'cattivi': 260,
#  'corresponded': 261,
#  'nickleby': 262,
#  'dyanne': 263,
#  'ferment': 264,
#  'caption': 265,
#  'tudors': 266,
#  'knowingly': 267,
#  'learner': 268,
#  'duddy': 269,
#  'nugent': 270,
#  'unpalatably': 271,
#  'hardesty': 272,
#  'marenghi': 273,
#  'campaigns': 274,
#  'winifred': 275,
#  'ebeneezer': 276,
#  'unignorable': 277,
#  'ands': 278,
#  'plotkurt': 279,
#  'sneakiness': 280,
#  'grave': 281,
#  'comic': 282,
#  'conservativism': 283,
#  'galleys': 284,
#  'fetishistic': 285,
#  'pleases': 286,
#  'affinity': 287,
#  'hynde': 288,
#  'discontented': 289,
#  'suffer': 290,
#  'importance': 291,
#  'regan': 292,
#  'rebe': 293,
#  'saat': 294,
#  'showing': 295,
#  'psychotically': 296,
#  'sthf': 297,
#  'possesing': 298,
#  'footloose': 299,
#  'intimidation': 300,
#  'topped': 301,
#  'electrocuting': 302,
#  'tsk': 303,
#  'chilled': 304,
#  'huang': 305,
#  'meteoric': 306,
#  'callus': 307,
#  'potently': 308,
#  'candians': 309,
#  'mediaeval': 310,
#  'matchup': 311,
#  'elicited': 312,
#  'buford': 313,
#  'shipmate': 314,
#  'hyller': 315,
#  'rearveiw': 316,
#  'overreacting': 317,
#  'lockyer': 318,
#  'months': 319,
#  'honk': 320,
#  'pushes': 321,
#  'unstated': 322,
#  'bondi': 323,
#  'mnniskor': 324,
#  'modestly': 325,
#  'johannes': 326,
#  'moving': 327,
#  'whodunit': 328,
#  'ranges': 329,
#  'confetti': 330,
#  'melted': 331,
#  'crystallized': 332,
#  'mary': 333,
#  'hopkins': 334,
#  'wildcats': 335,
#  'sobriety': 336,
#  'decorating': 337,
#  'aspiration': 338,
#  'sensuously': 339,
#  'duroy': 340,
#  'takeshi': 341,
#  'careering': 342,
#  'rejoiced': 343,
#  'amy': 344,
#  'lolita': 345,
#  'kayo': 346,
#  'paleontologist': 347,
#  'rounds': 348,
#  'sexes': 349,
#  'squeeze': 350,
#  'sicken': 351,
#  'bauble': 352,
#  'bodys': 353,
#  'chasey': 354,
#  'armor': 355,
#  'saucy': 356,
#  'bloss': 357,
#  'backwards': 358,
#  'reveal': 359,
#  'rural': 360,
#  'emerging': 361,
#  'cortland': 362,
#  'participated': 363,
#  'triana': 364,
#  'lived': 365,
#  'anymore': 366,
#  'wouldn': 367,
#  'poop': 368,
#  'revoked': 369,
#  'gwenneth': 370,
#  'aaliyah': 371,
#  'ilk': 372,
#  'fruitcake': 373,
#  'mexicans': 374,
#  'associate': 375,
#  'mellow': 376,
#  'expel': 377,
#  'accede': 378,
#  'fluctuating': 379,
#  'lenghth': 380,
#  'prejudiced': 381,
#  'walder': 382,
#  'billboards': 383,
#  'appreciation': 384,
#  'ruthless': 385,
#  'comin': 386,
#  'classist': 387,
#  'ozon': 388,
#  'squadroom': 389,
#  'ablaze': 390,
#  'bensonhurst': 391,
#  'disadvantageous': 392,
#  'idiomatic': 393,
#  'stretched': 394,
#  'stuyvesant': 395,
#  'prizzi': 396,
#  'gelded': 397,
#  'huber': 398,
#  'travelogue': 399,
#  'despised': 400,
#  'toplining': 401,
#  'pensacolians': 402,
#  'gleaming': 403,
#  'athol': 404,
#  'armpits': 405,
#  'bally': 406,
#  'saxophonists': 407,
#  'sniffed': 408,
#  'scandanavian': 409,
#  'ordained': 410,
#  'faiths': 411,
#  'garrett': 412,
#  'fannie': 413,
#  'incidentally': 414,
#  'akelly': 415,
#  'class': 416,
#  'yaks': 417,
#  'awkward': 418,
#  'supersoldier': 419,
#  'tolkiens': 420,
#  'sharikovs': 421,
#  'exurbia': 422,
#  'mouldy': 423,
#  'guys': 424,
#  'sahsa': 425,
#  'baffled': 426,
#  'saskatoon': 427,
#  'occurred': 428,
#  'juan': 429,
#  'hauser': 430,
#  'jewel': 431,
#  'airforce': 432,
#  'overbroad': 433,
#  'offsets': 434,
#  'granddaughter': 435,
#  'stuningly': 436,
#  'heading': 437,
#  'sphere': 438,
#  'buddist': 439,
#  'dread': 440,
#  'silverlake': 441,
#  'dispassionately': 442,
#  'doodle': 443,
#  'arriv': 444,
#  'hanfstaengel': 445,
#  'jardyce': 446,
#  'splattered': 447,
#  'pirouettes': 448,
#  'islanders': 449,
#  'gogh': 450,
#  'regalia': 451,
#  'hunted': 452,
#  'resorts': 453,
#  'jan': 454,
#  'bloodsucking': 455,
#  'societal': 456,
#  'meandered': 457,
#  'confidentiality': 458,
#  'tenancier': 459,
#  'ykai': 460,
#  'alissia': 461,
#  'meta': 462,
#  'jalousie': 463,
#  'sniffish': 464,
#  'hairdo': 465,
#  'farm': 466,
#  'jett': 467,
#  'malfatti': 468,
#  'veddar': 469,
#  'asteroids': 470,
#  'durbin': 471,
#  'sacramento': 472,
#  'termite': 473,
#  'stockton': 474,
#  'incompetence': 475,
#  'pe': 476,
#  'yau': 477,
#  'loggerheads': 478,
#  'dawson': 479,
#  'cabo': 480,
#  'trongard': 481,
#  'zelniker': 482,
#  'womanhood': 483,
#  'nobles': 484,
#  'dissectionist': 485,
#  'wuornos': 486,
#  'calibre': 487,
#  'macarther': 488,
#  'slightest': 489,
#  'loa': 490,
#  'copain': 491,
#  'imps': 492,
#  'punchline': 493,
#  'subsist': 494,
#  'batistabomb': 495,
#  'foe': 496,
#  'ruminations': 497,
#  'dimestore': 498,
#  'charistmatic': 499,
#  'identifies': 500,
#  'parc': 501,
#  'persona': 502,
#  'wathced': 503,
#  'fisheris': 504,
#  'descendents': 505,
#  'supplier': 506,
#  'belmondo': 507,
#  'gojoe': 508,
#  'beneficence': 509,
#  'aiken': 510,
#  'helo': 511,
#  'regent': 512,
#  'millers': 513,
#  'tootsie': 514,
#  'lightheartedness': 515,
#  'sendback': 516,
#  'tapes': 517,
#  'foxworthy': 518,
#  'maximally': 519,
#  'whiny': 520,
#  'samaritan': 521,
#  'astronaut': 522,
#  'overwatched': 523,
#  'unforgivably': 524,
#  'pyramid': 525,
#  'nepalese': 526,
#  'bunk': 527,
#  'misjudging': 528,
#  'recordings': 529,
#  'lense': 530,
#  'dixie': 531,
#  'mirkovich': 532,
#  'silos': 533,
#  'chattering': 534,
#  'rodder': 535,
#  'logline': 536,
#  'trekking': 537,
#  'jing': 538,
#  'intimacies': 539,
#  'conditions': 540,
#  'simmers': 541,
#  'tori': 542,
#  'psychologist': 543,
#  'anklet': 544,
#  'chomiak': 545,
#  'convergent': 546,
#  'nekromantik': 547,
#  'tisa': 548,
#  'rosenliski': 549,
#  'unanimousness': 550,
#  'unintenional': 551,
#  'protags': 552,
#  'contre': 553,
#  'replete': 554,
#  'brims': 555,
#  'footpath': 556,
#  'dozen': 557,
#  'bingo': 558,
#  'bubbling': 559,
#  'ezra': 560,
#  'montage': 561,
#  'seppuka': 562,
#  'lumiere': 563,
#  'unwaveringly': 564,
#  'crapfest': 565,
#  'andr': 566,
#  'strutts': 567,
#  'vitametavegamin': 568,
#  'palestijn': 569,
#  'thuggees': 570,
#  'orginality': 571,
#  'jellyfish': 572,
#  'lettich': 573,
#  'propagandic': 574,
#  'medalist': 575,
#  'purchased': 576,
#  'mcmanus': 577,
#  'bestiality': 578,
#  'evre': 579,
#  'winos': 580,
#  'criticised': 581,
#  'capiche': 582,
#  'workload': 583,
#  'venting': 584,
#  'arquette': 585,
#  'nerds': 586,
#  'coquette': 587,
#  'overseas': 588,
#  'grays': 589,
#  'excitingly': 590,
#  'bodice': 591,
#  'ravelling': 592,
#  'horler': 593,
#  'druten': 594,
#  'woohoo': 595,
#  'multistarrer': 596,
#  'inn': 597,
#  'catalogues': 598,
#  'trimble': 599,
#  'washrooms': 600,
#  'jain': 601,
#  'hetrakul': 602,
#  'biochemical': 603,
#  'accordian': 604,
#  'bergman': 605,
#  'wizardry': 606,
#  'zed': 607,
#  'congo': 608,
#  'medicinal': 609,
#  'brrr': 610,
#  'moskve': 611,
#  'prefigures': 612,
#  'concert': 613,
#  'menotti': 614,
#  'lousiness': 615,
#  'elmer': 616,
#  'dutt': 617,
#  'looniness': 618,
#  'turiqistan': 619,
#  'eliott': 620,
#  'hiking': 621,
#  'bomba': 622,
#  'banishses': 623,
#  'lene': 624,
#  'varies': 625,
#  'idiota': 626,
#  'lawton': 627,
#  'reissue': 628,
#  'princesse': 629,
#  'abhay': 630,
#  'underlying': 631,
#  'worth': 632,
#  'glo': 633,
#  'frannie': 634,
#  'pekinpah': 635,
#  'caligary': 636,
#  'ferzetti': 637,
#  'problem': 638,
#  'prosecutors': 639,
#  'bover': 640,
#  'bladck': 641,
#  'cloris': 642,
#  'confusions': 643,
#  'week': 644,
#  'unredeemable': 645,
#  'misunderstand': 646,
#  'rediscovering': 647,
#  'stew': 648,
#  'mastroianni': 649,
#  'phlegm': 650,
#  'wouldhave': 651,
#  'leterrier': 652,
#  'coulisses': 653,
#  'dummheit': 654,
#  'prescience': 655,
#  'happening': 656,
#  'santimoniousness': 657,
#  'reason': 658,
#  'hillermans': 659,
#  'thousand': 660,
#  'taints': 661,
#  'jcpenney': 662,
#  'uecker': 663,
#  'puppetry': 664,
#  'sexploitative': 665,
#  'reddin': 666,
#  'tainted': 667,
#  'popsicles': 668,
#  'leagues': 669,
#  'lindsay': 670,
#  'minogue': 671,
#  'natal': 672,
#  'trots': 673,
#  'gratuitously': 674,
#  'lutte': 675,
#  'breats': 676,
#  'discerned': 677,
#  'torme': 678,
#  'safari': 679,
#  'chevalia': 680,
#  'coincidently': 681,
#  'dyno': 682,
#  'stepmotherhood': 683,
#  'peddler': 684,
#  'tbu': 685,
#  'proven': 686,
#  'iago': 687,
#  'detractions': 688,
#  'stalwarts': 689,
#  'reclamation': 690,
#  'heidecke': 691,
#  'reunion': 692,
#  'insulate': 693,
#  'kanno': 694,
#  'piquantly': 695,
#  'beens': 696,
#  'adhesive': 697,
#  'leclerc': 698,
#  'hoshi': 699,
#  'eck': 700,
#  'comparrison': 701,
#  'troublesome': 702,
#  'reflected': 703,
#  'gw': 704,
#  'gfx': 705,
#  'thoroughly': 706,
#  'fragglerock': 707,
#  'slats': 708,
#  'influencee': 709,
#  'thunderstorms': 710,
#  'magalhes': 711,
#  'haber': 712,
#  'rouncewell': 713,
#  'tpb': 714,
#  'pianos': 715,
#  'fenn': 716,
#  'detecting': 717,
#  'wrrrooonnnnggg': 718,
#  'shareholders': 719,
#  'fanbase': 720,
#  'overdramatic': 721,
#  'bastketball': 722,
#  'indefinite': 723,
#  'advanced': 724,
#  'adela': 725,
#  'actorsthey': 726,
#  'autopsies': 727,
#  'renovations': 728,
#  'mahayana': 729,
#  'prescribe': 730,
#  'bandstand': 731,
#  'sexy': 732,
#  'becoming': 733,
#  'pork': 734,
#  'elson': 735,
#  'sharifi': 736,
#  'centre': 737,
#  'earls': 738,
#  'pelts': 739,
#  'haralambopoulos': 740,
#  'shootem': 741,
#  'glamouresque': 742,
#  'trinary': 743,
#  'budget': 744,
#  'explain': 745,
#  'mooching': 746,
#  'falsies': 747,
#  'costarred': 748,
#  'catalogued': 749,
#  'infestation': 750,
#  'najimi': 751,
#  'speedball': 752,
#  'jetliner': 753,
#  'trifles': 754,
#  'desi': 755,
#  'blazer': 756,
#  'fathering': 757,
#  'pixar': 758,
#  'detritus': 759,
#  'burying': 760,
#  'remedy': 761,
#  'dispite': 762,
#  'greatest': 763,
#  'ripping': 764,
#  'adjusted': 765,
#  'yada': 766,
#  'ditsy': 767,
#  'overabundance': 768,
#  'burping': 769,
#  'straddled': 770,
#  'eventide': 771,
#  'firmament': 772,
#  'dtr': 773,
#  'glom': 774,
#  'formosa': 775,
#  'stupifying': 776,
#  'taing': 777,
#  'capomezza': 778,
#  'monaca': 779,
#  'copies': 780,
#  'chelita': 781,
#  'amrican': 782,
#  'ellison': 783,
#  'paiyan': 784,
#  'floating': 785,
#  'entrapment': 786,
#  'diapered': 787,
#  'darden': 788,
#  'slvia': 789,
#  'flatulence': 790,
#  'cancellation': 791,
#  'glaucoma': 792,
#  'freaky': 793,
#  'hammond': 794,
#  'percy': 795,
#  'whimper': 796,
#  'saltwater': 797,
#  'mallaig': 798,
#  'anschel': 799,
#  'nondescript': 800,
#  'ingeniously': 801,
#  'filmographers': 802,
#  'sternwood': 803,
#  'unharmed': 804,
#  'unread': 805,
#  'witherspoon': 806,
#  'rewriting': 807,
#  'bannon': 808,
#  'gratuitious': 809,
#  'milkman': 810,
#  'pending': 811,
#  'reissued': 812,
#  'legitimacy': 813,
#  'architects': 814,
#  'marit': 815,
#  'flippin': 816,
#  'spliff': 817,
#  'nozawa': 818,
#  'culled': 819,
#  'smita': 820,
#  'tofu': 821,
#  'bailsman': 822,
#  'premonitions': 823,
#  'paracetamol': 824,
#  'gallows': 825,
#  'elk': 826,
#  'woods': 827,
#  'passage': 828,
#  'conclude': 829,
#  'segways': 830,
#  'braggart': 831,
#  'fanu': 832,
#  'low': 833,
#  'hastens': 834,
#  'altitude': 835,
#  'wage': 836,
#  'officially': 837,
#  'crescendoing': 838,
#  'marine': 839,
#  'meltdown': 840,
#  'wincott': 841,
#  'nymphomania': 842,
#  'crucifies': 843,
#  'oke': 844,
#  'franclisco': 845,
#  'muffat': 846,
#  'lockers': 847,
#  'paraphrase': 848,
#  'inconspicuous': 849,
#  'snob': 850,
#  'dawg': 851,
#  'drunkeness': 852,
#  'collusion': 853,
#  'chalant': 854,
#  'bugle': 855,
#  'excel': 856,
#  'moors': 857,
#  'elitist': 858,
#  'griping': 859,
#  'aria': 860,
#  'thingee': 861,
#  'confident': 862,
#  'manfully': 863,
#  'insturmental': 864,
#  'teletubbies': 865,
#  'movements': 866,
#  'ific': 867,
#  'confound': 868,
#  'hoses': 869,
#  'tt': 870,
#  'silverstein': 871,
#  'trashy': 872,
#  'according': 873,
#  'wait': 874,
#  'heartland': 875,
#  'sirico': 876,
#  'donatello': 877,
#  'jeongg': 878,
#  'interpreted': 879,
#  'bootlegging': 880,
#  'drosselmeyer': 881,
#  'dismissal': 882,
#  'wished': 883,
#  'dareus': 884,
#  'suhaag': 885,
#  'klutz': 886,
#  'bridget': 887,
#  'weww': 888,
#  'favorit': 889,
#  'igniminiously': 890,
#  'entwines': 891,
#  'tana': 892,
#  'imc': 893,
#  'whalin': 894,
#  'noughties': 895,
#  'sumpin': 896,
#  'boooooooo': 897,
#  'harming': 898,
#  'pace': 899,
#  'collections': 900,
#  'cource': 901,
#  'dependence': 902,
#  'aspired': 903,
#  'spoilerish': 904,
#  'unexploded': 905,
#  'utrillo': 906,
#  'toyomichi': 907,
#  'position': 908,
#  'gentlemanly': 909,
#  'treason': 910,
#  'thinly': 911,
#  'deckchair': 912,
#  'temuco': 913,
#  'filmographies': 914,
#  'governmentally': 915,
#  'gujerati': 916,
#  'scouting': 917,
#  'lenders': 918,
#  'goldsman': 919,
#  'romp': 920,
#  'tricia': 921,
#  'ringo': 922,
#  'nincompoops': 923,
#  'sierras': 924,
#  'okinawan': 925,
#  'amine': 926,
#  'somesuch': 927,
#  'viscous': 928,
#  'brooklyners': 929,
#  'sceneries': 930,
#  'jasonx': 931,
#  'taciturn': 932,
#  'bulette': 933,
#  'shooting': 934,
#  'harlow': 935,
#  'gaye': 936,
#  'affirms': 937,
#  'intricacies': 938,
#  'saran': 939,
#  'loopy': 940,
#  'simba': 941,
#  'sofa': 942,
#  'capitalists': 943,
#  'densely': 944,
#  'enigmas': 945,
#  'annoyingly': 946,
#  'muppeteers': 947,
#  'audrina': 948,
#  'psicoanalitical': 949,
#  'purge': 950,
#  'hooves': 951,
#  'rottens': 952,
#  'conquerors': 953,
#  'fortnight': 954,
#  'amatuer': 955,
#  'leger': 956,
#  'haye': 957,
#  'jeaneane': 958,
#  'hogan': 959,
#  'elase': 960,
#  'exhibited': 961,
#  'molesting': 962,
#  'repulse': 963,
#  'prevails': 964,
#  'progressed': 965,
#  'marginalizes': 966,
#  'expressionless': 967,
#  'chaeles': 968,
#  'aladdin': 969,
#  'britton': 970,
#  'completer': 971,
#  'postlesumthingor': 972,
#  'va': 973,
#  'paperback': 974,
#  'unbelievability': 975,
#  'soninha': 976,
#  'droppingly': 977,
#  'sexa': 978,
#  'sharif': 979,
#  'mechanics': 980,
#  'prodigiously': 981,
#  'natalie': 982,
#  'completes': 983,
#  'heady': 984,
#  'bunkum': 985,
#  'sweating': 986,
#  'autobiograhical': 987,
#  'excessive': 988,
#  'forefather': 989,
#  'ironhead': 990,
#  'underpants': 991,
#  'fastforward': 992,
#  'faschist': 993,
#  'camp': 994,
#  'toasts': 995,
#  'ronni': 996,
#  'direstion': 997,
#  'deletion': 998,
#  'envying': 999,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    for word in review.split(" "):
        layer_0[0][word2index[word]] +=1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    return 1 if label == 'POSITIVE' else 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        # populate review_vocab with all of the words in the given reviews
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)

        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        # populate label_vocab with all of the words in the given labels.
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights

        # These are the weights between the input layer and the hidden layer.
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        # These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        # The input layer, a two-dimensional matrix with shape 1 x input_nodes
        self.layer_0 = np.zeros((1,input_nodes))
    
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review.split(" "):
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        # make sure out we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        print(len(training_reviews))
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            review = training_reviews[i]
            label = training_labels[i]
            
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.

            # Forward Pass
            self.update_input_layer(review)
            layer_1 = np.dot(self.layer_0, self.weights_0_1)
            layer_2 = np.dot(layer_1, self.weights_1_2)
            y_hat = self.sigmoid(layer_2)
            
            if i == 0:
                print(self.weights_0_1.shape)
                print(self.weights_1_2.shape)
                print(self.layer_0.shape)
                print(layer_1.shape)
                print(y_hat.shape)

            # Calculate Error and Error Term
            y = self.get_target_for_label(label)
            err_out = y_hat - y
            err_term_out = err_out * self.sigmoid_output_2_derivative(y_hat)

            if i == 0:
                print(np.array(y).shape)
                print(np.array(err_out).shape)
                print(np.array(err_term_out).shape)

            # Backpropagation Pass
            err_1 = np.dot(err_term_out, self.weights_1_2.T)
            err_term_1 = err_1
            
            if i == 0:
                print(err_1.shape)
                print(err_term_1.shape)

            # update the weights
            self.weights_1_2 -= self.learning_rate * np.dot(layer_1.T, err_term_out)
            self.weights_0_1 -= self.learning_rate * np.dot(self.layer_0.T, err_term_1)
            
            if i == 0:
                print(layer_1.T.shape, err_term_out.shape)
                print(self.layer_0.T.shape, err_term_1.shape)


            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            if(y_hat >= 0.5 and label == 'POSITIVE'):
                correct_so_far += 1
            elif(y_hat < 0.5 and label == 'NEGATIVE'):
                correct_so_far += 1

            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        print("len(testing_reviews)", len(testing_reviews))
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            print(pred)
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """

        # Forward Passs
        self.update_input_layer(review.lower())
        layer_1 = np.dot(self.layer_0, self.weights_0_1)
        layer_2 = np.dot(layer_1, self.weights_1_2)
        y_hat = self.sigmoid(layer_2)
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        print(y_hat)
        if y_hat >= 0.5:
            return 'POSITIVE'
        else:
            return 'NEGATIVE'

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# len(testing_reviews) 1000
# [[ 0.5]]
# POSITIVE
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Tested:1 Testing Accuracy:100.%[[ 0.5]]
# POSITIVE
# Progress:0.1% Speed(reviews/sec):183.1 #Correct:1 #Tested:2 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:0.2% Speed(reviews/sec):269.6 #Correct:2 #Tested:3 Testing Accuracy:66.6%[[ 0.5]]
# POSITIVE
# Progress:0.3% Speed(reviews/sec):328.0 #Correct:2 #Tested:4 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:0.4% Speed(reviews/sec):378.1 #Correct:3 #Tested:5 Testing Accuracy:60.0%[[ 0.5]]
# POSITIVE
# Progress:0.5% Speed(reviews/sec):413.9 #Correct:3 #Tested:6 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:0.6% Speed(reviews/sec):436.1 #Correct:4 #Tested:7 Testing Accuracy:57.1%[[ 0.5]]
# POSITIVE
# Progress:0.7% Speed(reviews/sec):458.2 #Correct:4 #Tested:8 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:0.8% Speed(reviews/sec):477.1 #Correct:5 #Tested:9 Testing Accuracy:55.5%[[ 0.5]]
# POSITIVE
# Progress:0.9% Speed(reviews/sec):466.5 #Correct:5 #Tested:10 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:1.0% Speed(reviews/sec):478.7 #Correct:6 #Tested:11 Testing Accuracy:54.5%[[ 0.5]]
# POSITIVE
# Progress:1.1% Speed(reviews/sec):490.7 #Correct:6 #Tested:12 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:1.2% Speed(reviews/sec):500.1 #Correct:7 #Tested:13 Testing Accuracy:53.8%[[ 0.5]]
# POSITIVE
# Progress:1.3% Speed(reviews/sec):507.4 #Correct:7 #Tested:14 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:1.4% Speed(reviews/sec):515.7 #Correct:8 #Tested:15 Testing Accuracy:53.3%[[ 0.5]]
# POSITIVE
# Progress:1.5% Speed(reviews/sec):524.0 #Correct:8 #Tested:16 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:1.6% Speed(reviews/sec):518.2 #Correct:9 #Tested:17 Testing Accuracy:52.9%[[ 0.5]]
# POSITIVE
# Progress:1.7% Speed(reviews/sec):522.4 #Correct:9 #Tested:18 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:1.8% Speed(reviews/sec):530.8 #Correct:10 #Tested:19 Testing Accuracy:52.6%[[ 0.5]]
# POSITIVE
# Progress:1.9% Speed(reviews/sec):534.7 #Correct:10 #Tested:20 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:2.0% Speed(reviews/sec):534.0 #Correct:11 #Tested:21 Testing Accuracy:52.3%[[ 0.5]]
# POSITIVE
# Progress:2.1% Speed(reviews/sec):537.8 #Correct:11 #Tested:22 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:2.2% Speed(reviews/sec):540.2 #Correct:12 #Tested:23 Testing Accuracy:52.1%[[ 0.5]]
# POSITIVE
# Progress:2.3% Speed(reviews/sec):540.9 #Correct:12 #Tested:24 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:2.4% Speed(reviews/sec):537.2 #Correct:13 #Tested:25 Testing Accuracy:52.0%[[ 0.5]]
# POSITIVE
# Progress:2.5% Speed(reviews/sec):541.2 #Correct:13 #Tested:26 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:2.6% Speed(reviews/sec):546.0 #Correct:14 #Tested:27 Testing Accuracy:51.8%[[ 0.5]]
# POSITIVE
# Progress:2.7% Speed(reviews/sec):535.7 #Correct:14 #Tested:28 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:2.8% Speed(reviews/sec):538.7 #Correct:15 #Tested:29 Testing Accuracy:51.7%[[ 0.5]]
# POSITIVE
# Progress:2.9% Speed(reviews/sec):540.1 #Correct:15 #Tested:30 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:3.0% Speed(reviews/sec):540.2 #Correct:16 #Tested:31 Testing Accuracy:51.6%[[ 0.5]]
# POSITIVE
# Progress:3.1% Speed(reviews/sec):543.5 #Correct:16 #Tested:32 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:3.2% Speed(reviews/sec):545.6 #Correct:17 #Tested:33 Testing Accuracy:51.5%[[ 0.5]]
# POSITIVE
# Progress:3.3% Speed(reviews/sec):548.3 #Correct:17 #Tested:34 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:3.4% Speed(reviews/sec):548.6 #Correct:18 #Tested:35 Testing Accuracy:51.4%[[ 0.5]]
# POSITIVE
# Progress:3.5% Speed(reviews/sec):551.4 #Correct:18 #Tested:36 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:3.6% Speed(reviews/sec):551.6 #Correct:19 #Tested:37 Testing Accuracy:51.3%[[ 0.5]]
# POSITIVE
# Progress:3.7% Speed(reviews/sec):555.4 #Correct:19 #Tested:38 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:3.8% Speed(reviews/sec):555.0 #Correct:20 #Tested:39 Testing Accuracy:51.2%[[ 0.5]]
# POSITIVE
# Progress:3.9% Speed(reviews/sec):550.3 #Correct:20 #Tested:40 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:4.0% Speed(reviews/sec):551.3 #Correct:21 #Tested:41 Testing Accuracy:51.2%[[ 0.5]]
# POSITIVE
# Progress:4.1% Speed(reviews/sec):553.3 #Correct:21 #Tested:42 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:4.2% Speed(reviews/sec):549.1 #Correct:22 #Tested:43 Testing Accuracy:51.1%[[ 0.5]]
# POSITIVE
# Progress:4.3% Speed(reviews/sec):548.3 #Correct:22 #Tested:44 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:4.4% Speed(reviews/sec):545.3 #Correct:23 #Tested:45 Testing Accuracy:51.1%[[ 0.5]]
# POSITIVE
# Progress:4.5% Speed(reviews/sec):538.6 #Correct:23 #Tested:46 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:4.6% Speed(reviews/sec):536.8 #Correct:24 #Tested:47 Testing Accuracy:51.0%[[ 0.5]]
# POSITIVE
# Progress:4.7% Speed(reviews/sec):539.7 #Correct:24 #Tested:48 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:4.8% Speed(reviews/sec):539.1 #Correct:25 #Tested:49 Testing Accuracy:51.0%[[ 0.5]]
# POSITIVE
# Progress:4.9% Speed(reviews/sec):539.3 #Correct:25 #Tested:50 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:5.0% Speed(reviews/sec):541.7 #Correct:26 #Tested:51 Testing Accuracy:50.9%[[ 0.5]]
# POSITIVE
# Progress:5.1% Speed(reviews/sec):544.3 #Correct:26 #Tested:52 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:5.2% Speed(reviews/sec):542.7 #Correct:27 #Tested:53 Testing Accuracy:50.9%[[ 0.5]]
# POSITIVE
# Progress:5.3% Speed(reviews/sec):544.2 #Correct:27 #Tested:54 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:5.4% Speed(reviews/sec):546.4 #Correct:28 #Tested:55 Testing Accuracy:50.9%[[ 0.5]]
# POSITIVE
# Progress:5.5% Speed(reviews/sec):549.2 #Correct:28 #Tested:56 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:5.6% Speed(reviews/sec):541.7 #Correct:29 #Tested:57 Testing Accuracy:50.8%[[ 0.5]]
# POSITIVE
# Progress:5.7% Speed(reviews/sec):543.2 #Correct:29 #Tested:58 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:5.8% Speed(reviews/sec):544.9 #Correct:30 #Tested:59 Testing Accuracy:50.8%[[ 0.5]]
# POSITIVE
# Progress:5.9% Speed(reviews/sec):546.8 #Correct:30 #Tested:60 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:6.0% Speed(reviews/sec):545.6 #Correct:31 #Tested:61 Testing Accuracy:50.8%[[ 0.5]]
# POSITIVE
# Progress:6.1% Speed(reviews/sec):546.1 #Correct:31 #Tested:62 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:6.2% Speed(reviews/sec):548.5 #Correct:32 #Tested:63 Testing Accuracy:50.7%[[ 0.5]]
# POSITIVE
# Progress:6.3% Speed(reviews/sec):550.4 #Correct:32 #Tested:64 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:6.4% Speed(reviews/sec):549.3 #Correct:33 #Tested:65 Testing Accuracy:50.7%[[ 0.5]]
# POSITIVE
# Progress:6.5% Speed(reviews/sec):551.0 #Correct:33 #Tested:66 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:6.6% Speed(reviews/sec):552.8 #Correct:34 #Tested:67 Testing Accuracy:50.7%[[ 0.5]]
# POSITIVE
# Progress:6.7% Speed(reviews/sec):553.8 #Correct:34 #Tested:68 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:6.8% Speed(reviews/sec):555.0 #Correct:35 #Tested:69 Testing Accuracy:50.7%[[ 0.5]]
# POSITIVE
# Progress:6.9% Speed(reviews/sec):554.9 #Correct:35 #Tested:70 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:7.0% Speed(reviews/sec):554.7 #Correct:36 #Tested:71 Testing Accuracy:50.7%[[ 0.5]]
# POSITIVE
# Progress:7.1% Speed(reviews/sec):556.9 #Correct:36 #Tested:72 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:7.2% Speed(reviews/sec):558.5 #Correct:37 #Tested:73 Testing Accuracy:50.6%[[ 0.5]]
# POSITIVE
# Progress:7.3% Speed(reviews/sec):560.1 #Correct:37 #Tested:74 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:7.4% Speed(reviews/sec):560.9 #Correct:38 #Tested:75 Testing Accuracy:50.6%[[ 0.5]]
# POSITIVE
# Progress:7.5% Speed(reviews/sec):561.5 #Correct:38 #Tested:76 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:7.6% Speed(reviews/sec):562.8 #Correct:39 #Tested:77 Testing Accuracy:50.6%[[ 0.5]]
# POSITIVE
# Progress:7.7% Speed(reviews/sec):563.9 #Correct:39 #Tested:78 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:7.8% Speed(reviews/sec):564.8 #Correct:40 #Tested:79 Testing Accuracy:50.6%[[ 0.5]]
# POSITIVE
# Progress:7.9% Speed(reviews/sec):565.5 #Correct:40 #Tested:80 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:8.0% Speed(reviews/sec):566.4 #Correct:41 #Tested:81 Testing Accuracy:50.6%[[ 0.5]]
# POSITIVE
# Progress:8.1% Speed(reviews/sec):561.0 #Correct:41 #Tested:82 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:8.2% Speed(reviews/sec):560.6 #Correct:42 #Tested:83 Testing Accuracy:50.6%[[ 0.5]]
# POSITIVE
# Progress:8.3% Speed(reviews/sec):560.1 #Correct:42 #Tested:84 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:8.4% Speed(reviews/sec):560.9 #Correct:43 #Tested:85 Testing Accuracy:50.5%[[ 0.5]]
# POSITIVE
# Progress:8.5% Speed(reviews/sec):561.3 #Correct:43 #Tested:86 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:8.6% Speed(reviews/sec):560.4 #Correct:44 #Tested:87 Testing Accuracy:50.5%[[ 0.5]]
# POSITIVE
# Progress:8.7% Speed(reviews/sec):561.3 #Correct:44 #Tested:88 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:8.8% Speed(reviews/sec):562.3 #Correct:45 #Tested:89 Testing Accuracy:50.5%[[ 0.5]]
# POSITIVE
# Progress:8.9% Speed(reviews/sec):559.3 #Correct:45 #Tested:90 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:9.0% Speed(reviews/sec):558.9 #Correct:46 #Tested:91 Testing Accuracy:50.5%[[ 0.5]]
# POSITIVE
# Progress:9.1% Speed(reviews/sec):559.2 #Correct:46 #Tested:92 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:9.2% Speed(reviews/sec):559.9 #Correct:47 #Tested:93 Testing Accuracy:50.5%[[ 0.5]]
# POSITIVE
# Progress:9.3% Speed(reviews/sec):560.2 #Correct:47 #Tested:94 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:9.4% Speed(reviews/sec):561.1 #Correct:48 #Tested:95 Testing Accuracy:50.5%[[ 0.5]]
# POSITIVE
# Progress:9.5% Speed(reviews/sec):561.0 #Correct:48 #Tested:96 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:9.6% Speed(reviews/sec):561.0 #Correct:49 #Tested:97 Testing Accuracy:50.5%[[ 0.5]]
# POSITIVE
# Progress:9.7% Speed(reviews/sec):560.5 #Correct:49 #Tested:98 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:9.8% Speed(reviews/sec):561.6 #Correct:50 #Tested:99 Testing Accuracy:50.5%[[ 0.5]]
# POSITIVE
# Progress:9.9% Speed(reviews/sec):562.5 #Correct:50 #Tested:100 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:10.0% Speed(reviews/sec):563.1 #Correct:51 #Tested:101 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:10.1% Speed(reviews/sec):563.7 #Correct:51 #Tested:102 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:10.2% Speed(reviews/sec):564.4 #Correct:52 #Tested:103 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:10.3% Speed(reviews/sec):563.4 #Correct:52 #Tested:104 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:10.4% Speed(reviews/sec):564.3 #Correct:53 #Tested:105 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:10.5% Speed(reviews/sec):565.6 #Correct:53 #Tested:106 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:10.6% Speed(reviews/sec):565.8 #Correct:54 #Tested:107 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:10.7% Speed(reviews/sec):566.6 #Correct:54 #Tested:108 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:10.8% Speed(reviews/sec):567.6 #Correct:55 #Tested:109 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:10.9% Speed(reviews/sec):568.4 #Correct:55 #Tested:110 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:11.0% Speed(reviews/sec):568.1 #Correct:56 #Tested:111 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:11.1% Speed(reviews/sec):568.0 #Correct:56 #Tested:112 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:11.2% Speed(reviews/sec):567.9 #Correct:57 #Tested:113 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:11.3% Speed(reviews/sec):567.4 #Correct:57 #Tested:114 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:11.4% Speed(reviews/sec):558.3 #Correct:58 #Tested:115 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:11.5% Speed(reviews/sec):557.7 #Correct:58 #Tested:116 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:11.6% Speed(reviews/sec):557.7 #Correct:59 #Tested:117 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:11.7% Speed(reviews/sec):556.9 #Correct:59 #Tested:118 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:11.8% Speed(reviews/sec):557.3 #Correct:60 #Tested:119 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:11.9% Speed(reviews/sec):557.2 #Correct:60 #Tested:120 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:12.0% Speed(reviews/sec):557.6 #Correct:61 #Tested:121 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:12.1% Speed(reviews/sec):558.2 #Correct:61 #Tested:122 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:12.2% Speed(reviews/sec):558.8 #Correct:62 #Tested:123 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:12.3% Speed(reviews/sec):558.1 #Correct:62 #Tested:124 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:12.4% Speed(reviews/sec):558.1 #Correct:63 #Tested:125 Testing Accuracy:50.4%[[ 0.5]]
# POSITIVE
# Progress:12.5% Speed(reviews/sec):558.0 #Correct:63 #Tested:126 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:12.6% Speed(reviews/sec):558.7 #Correct:64 #Tested:127 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:12.7% Speed(reviews/sec):558.4 #Correct:64 #Tested:128 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:12.8% Speed(reviews/sec):559.0 #Correct:65 #Tested:129 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:12.9% Speed(reviews/sec):559.6 #Correct:65 #Tested:130 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:13.0% Speed(reviews/sec):560.2 #Correct:66 #Tested:131 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:13.1% Speed(reviews/sec):560.9 #Correct:66 #Tested:132 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:13.2% Speed(reviews/sec):561.7 #Correct:67 #Tested:133 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:13.3% Speed(reviews/sec):562.4 #Correct:67 #Tested:134 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:13.4% Speed(reviews/sec):562.4 #Correct:68 #Tested:135 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:13.5% Speed(reviews/sec):562.2 #Correct:68 #Tested:136 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:13.6% Speed(reviews/sec):562.8 #Correct:69 #Tested:137 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:13.7% Speed(reviews/sec):563.5 #Correct:69 #Tested:138 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:13.8% Speed(reviews/sec):564.1 #Correct:70 #Tested:139 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:13.9% Speed(reviews/sec):563.8 #Correct:70 #Tested:140 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:14.0% Speed(reviews/sec):564.8 #Correct:71 #Tested:141 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:14.1% Speed(reviews/sec):565.1 #Correct:71 #Tested:142 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:14.2% Speed(reviews/sec):565.8 #Correct:72 #Tested:143 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:14.3% Speed(reviews/sec):566.5 #Correct:72 #Tested:144 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:14.4% Speed(reviews/sec):566.4 #Correct:73 #Tested:145 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:14.5% Speed(reviews/sec):567.0 #Correct:73 #Tested:146 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:14.6% Speed(reviews/sec):566.6 #Correct:74 #Tested:147 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:14.7% Speed(reviews/sec):566.9 #Correct:74 #Tested:148 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:14.8% Speed(reviews/sec):566.3 #Correct:75 #Tested:149 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:14.9% Speed(reviews/sec):566.5 #Correct:75 #Tested:150 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:15.0% Speed(reviews/sec):566.8 #Correct:76 #Tested:151 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:15.1% Speed(reviews/sec):567.1 #Correct:76 #Tested:152 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:15.2% Speed(reviews/sec):566.6 #Correct:77 #Tested:153 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:15.3% Speed(reviews/sec):566.1 #Correct:77 #Tested:154 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:15.4% Speed(reviews/sec):566.7 #Correct:78 #Tested:155 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:15.5% Speed(reviews/sec):566.9 #Correct:78 #Tested:156 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:15.6% Speed(reviews/sec):566.6 #Correct:79 #Tested:157 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:15.7% Speed(reviews/sec):566.6 #Correct:79 #Tested:158 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:15.8% Speed(reviews/sec):567.2 #Correct:80 #Tested:159 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:15.9% Speed(reviews/sec):567.7 #Correct:80 #Tested:160 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:16.0% Speed(reviews/sec):567.8 #Correct:81 #Tested:161 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:16.1% Speed(reviews/sec):567.9 #Correct:81 #Tested:162 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:16.2% Speed(reviews/sec):568.4 #Correct:82 #Tested:163 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:16.3% Speed(reviews/sec):569.0 #Correct:82 #Tested:164 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:16.4% Speed(reviews/sec):569.7 #Correct:83 #Tested:165 Testing Accuracy:50.3%[[ 0.5]]
# POSITIVE
# Progress:16.5% Speed(reviews/sec):569.5 #Correct:83 #Tested:166 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:16.6% Speed(reviews/sec):569.6 #Correct:84 #Tested:167 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:16.7% Speed(reviews/sec):569.4 #Correct:84 #Tested:168 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:16.8% Speed(reviews/sec):570.1 #Correct:85 #Tested:169 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:16.9% Speed(reviews/sec):570.6 #Correct:85 #Tested:170 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:17.0% Speed(reviews/sec):570.8 #Correct:86 #Tested:171 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:17.1% Speed(reviews/sec):571.4 #Correct:86 #Tested:172 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:17.2% Speed(reviews/sec):570.9 #Correct:87 #Tested:173 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:17.3% Speed(reviews/sec):571.1 #Correct:87 #Tested:174 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:17.4% Speed(reviews/sec):571.3 #Correct:88 #Tested:175 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:17.5% Speed(reviews/sec):571.8 #Correct:88 #Tested:176 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:17.6% Speed(reviews/sec):572.3 #Correct:89 #Tested:177 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:17.7% Speed(reviews/sec):572.4 #Correct:89 #Tested:178 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:17.8% Speed(reviews/sec):573.1 #Correct:90 #Tested:179 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:17.9% Speed(reviews/sec):573.6 #Correct:90 #Tested:180 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:18.0% Speed(reviews/sec):573.5 #Correct:91 #Tested:181 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:18.1% Speed(reviews/sec):573.9 #Correct:91 #Tested:182 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:18.2% Speed(reviews/sec):573.8 #Correct:92 #Tested:183 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:18.3% Speed(reviews/sec):574.1 #Correct:92 #Tested:184 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:18.4% Speed(reviews/sec):573.5 #Correct:93 #Tested:185 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:18.5% Speed(reviews/sec):573.6 #Correct:93 #Tested:186 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:18.6% Speed(reviews/sec):574.2 #Correct:94 #Tested:187 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:18.7% Speed(reviews/sec):574.3 #Correct:94 #Tested:188 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:18.8% Speed(reviews/sec):574.3 #Correct:95 #Tested:189 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:18.9% Speed(reviews/sec):574.6 #Correct:95 #Tested:190 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:19.0% Speed(reviews/sec):575.2 #Correct:96 #Tested:191 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:19.1% Speed(reviews/sec):575.8 #Correct:96 #Tested:192 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:19.2% Speed(reviews/sec):576.4 #Correct:97 #Tested:193 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:19.3% Speed(reviews/sec):576.0 #Correct:97 #Tested:194 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:19.4% Speed(reviews/sec):576.7 #Correct:98 #Tested:195 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:19.5% Speed(reviews/sec):577.0 #Correct:98 #Tested:196 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:19.6% Speed(reviews/sec):576.9 #Correct:99 #Tested:197 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:19.7% Speed(reviews/sec):577.3 #Correct:99 #Tested:198 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:19.8% Speed(reviews/sec):578.0 #Correct:100 #Tested:199 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:19.9% Speed(reviews/sec):578.3 #Correct:100 #Tested:200 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:20.0% Speed(reviews/sec):579.1 #Correct:101 #Tested:201 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:20.1% Speed(reviews/sec):579.3 #Correct:101 #Tested:202 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:20.2% Speed(reviews/sec):579.9 #Correct:102 #Tested:203 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:20.3% Speed(reviews/sec):579.9 #Correct:102 #Tested:204 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:20.4% Speed(reviews/sec):580.4 #Correct:103 #Tested:205 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:20.5% Speed(reviews/sec):580.8 #Correct:103 #Tested:206 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:20.6% Speed(reviews/sec):580.5 #Correct:104 #Tested:207 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:20.7% Speed(reviews/sec):580.7 #Correct:104 #Tested:208 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:20.8% Speed(reviews/sec):581.0 #Correct:105 #Tested:209 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:20.9% Speed(reviews/sec):580.7 #Correct:105 #Tested:210 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:21.0% Speed(reviews/sec):581.0 #Correct:106 #Tested:211 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:21.1% Speed(reviews/sec):581.5 #Correct:106 #Tested:212 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:21.2% Speed(reviews/sec):582.0 #Correct:107 #Tested:213 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:21.3% Speed(reviews/sec):580.8 #Correct:107 #Tested:214 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:21.4% Speed(reviews/sec):581.3 #Correct:108 #Tested:215 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:21.5% Speed(reviews/sec):581.1 #Correct:108 #Tested:216 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:21.6% Speed(reviews/sec):581.5 #Correct:109 #Tested:217 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:21.7% Speed(reviews/sec):581.3 #Correct:109 #Tested:218 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:21.8% Speed(reviews/sec):581.2 #Correct:110 #Tested:219 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:21.9% Speed(reviews/sec):581.8 #Correct:110 #Tested:220 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:22.0% Speed(reviews/sec):581.7 #Correct:111 #Tested:221 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:22.1% Speed(reviews/sec):582.0 #Correct:111 #Tested:222 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:22.2% Speed(reviews/sec):582.3 #Correct:112 #Tested:223 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:22.3% Speed(reviews/sec):582.3 #Correct:112 #Tested:224 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:22.4% Speed(reviews/sec):581.0 #Correct:113 #Tested:225 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:22.5% Speed(reviews/sec):581.0 #Correct:113 #Tested:226 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:22.6% Speed(reviews/sec):580.0 #Correct:114 #Tested:227 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:22.7% Speed(reviews/sec):580.1 #Correct:114 #Tested:228 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:22.8% Speed(reviews/sec):580.2 #Correct:115 #Tested:229 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:22.9% Speed(reviews/sec):580.3 #Correct:115 #Tested:230 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:23.0% Speed(reviews/sec):579.7 #Correct:116 #Tested:231 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:23.1% Speed(reviews/sec):579.6 #Correct:116 #Tested:232 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:23.2% Speed(reviews/sec):580.1 #Correct:117 #Tested:233 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:23.3% Speed(reviews/sec):580.3 #Correct:117 #Tested:234 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:23.4% Speed(reviews/sec):579.6 #Correct:118 #Tested:235 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:23.5% Speed(reviews/sec):574.9 #Correct:118 #Tested:236 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:23.6% Speed(reviews/sec):573.7 #Correct:119 #Tested:237 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:23.7% Speed(reviews/sec):573.5 #Correct:119 #Tested:238 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:23.8% Speed(reviews/sec):573.5 #Correct:120 #Tested:239 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:23.9% Speed(reviews/sec):573.4 #Correct:120 #Tested:240 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:24.0% Speed(reviews/sec):573.1 #Correct:121 #Tested:241 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:24.1% Speed(reviews/sec):573.2 #Correct:121 #Tested:242 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:24.2% Speed(reviews/sec):573.3 #Correct:122 #Tested:243 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:24.3% Speed(reviews/sec):573.0 #Correct:122 #Tested:244 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:24.4% Speed(reviews/sec):573.2 #Correct:123 #Tested:245 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:24.5% Speed(reviews/sec):573.6 #Correct:123 #Tested:246 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:24.6% Speed(reviews/sec):574.1 #Correct:124 #Tested:247 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:24.7% Speed(reviews/sec):574.3 #Correct:124 #Tested:248 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:24.8% Speed(reviews/sec):574.9 #Correct:125 #Tested:249 Testing Accuracy:50.2%[[ 0.5]]
# POSITIVE
# Progress:24.9% Speed(reviews/sec):575.3 #Correct:125 #Tested:250 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:25.0% Speed(reviews/sec):575.8 #Correct:126 #Tested:251 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:25.1% Speed(reviews/sec):576.2 #Correct:126 #Tested:252 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:25.2% Speed(reviews/sec):576.5 #Correct:127 #Tested:253 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:25.3% Speed(reviews/sec):576.8 #Correct:127 #Tested:254 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:25.4% Speed(reviews/sec):577.3 #Correct:128 #Tested:255 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:25.5% Speed(reviews/sec):577.7 #Correct:128 #Tested:256 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:25.6% Speed(reviews/sec):578.3 #Correct:129 #Tested:257 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:25.7% Speed(reviews/sec):578.8 #Correct:129 #Tested:258 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:25.8% Speed(reviews/sec):579.3 #Correct:130 #Tested:259 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:25.9% Speed(reviews/sec):579.6 #Correct:130 #Tested:260 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:26.0% Speed(reviews/sec):580.1 #Correct:131 #Tested:261 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:26.1% Speed(reviews/sec):580.6 #Correct:131 #Tested:262 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:26.2% Speed(reviews/sec):580.8 #Correct:132 #Tested:263 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:26.3% Speed(reviews/sec):580.6 #Correct:132 #Tested:264 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:26.4% Speed(reviews/sec):580.9 #Correct:133 #Tested:265 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:26.5% Speed(reviews/sec):580.5 #Correct:133 #Tested:266 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:26.6% Speed(reviews/sec):580.8 #Correct:134 #Tested:267 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:26.7% Speed(reviews/sec):580.9 #Correct:134 #Tested:268 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:26.8% Speed(reviews/sec):581.2 #Correct:135 #Tested:269 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:26.9% Speed(reviews/sec):581.6 #Correct:135 #Tested:270 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:27.0% Speed(reviews/sec):581.7 #Correct:136 #Tested:271 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:27.1% Speed(reviews/sec):581.9 #Correct:136 #Tested:272 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:27.2% Speed(reviews/sec):581.7 #Correct:137 #Tested:273 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:27.3% Speed(reviews/sec):582.2 #Correct:137 #Tested:274 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:27.4% Speed(reviews/sec):582.1 #Correct:138 #Tested:275 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:27.5% Speed(reviews/sec):581.5 #Correct:138 #Tested:276 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:27.6% Speed(reviews/sec):581.8 #Correct:139 #Tested:277 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:27.7% Speed(reviews/sec):581.8 #Correct:139 #Tested:278 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:27.8% Speed(reviews/sec):582.1 #Correct:140 #Tested:279 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:27.9% Speed(reviews/sec):582.4 #Correct:140 #Tested:280 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:28.0% Speed(reviews/sec):582.7 #Correct:141 #Tested:281 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:28.1% Speed(reviews/sec):583.1 #Correct:141 #Tested:282 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:28.2% Speed(reviews/sec):583.6 #Correct:142 #Tested:283 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:28.3% Speed(reviews/sec):584.0 #Correct:142 #Tested:284 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:28.4% Speed(reviews/sec):582.9 #Correct:143 #Tested:285 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:28.5% Speed(reviews/sec):583.2 #Correct:143 #Tested:286 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:28.6% Speed(reviews/sec):583.7 #Correct:144 #Tested:287 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:28.7% Speed(reviews/sec):584.1 #Correct:144 #Tested:288 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:28.8% Speed(reviews/sec):584.6 #Correct:145 #Tested:289 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:28.9% Speed(reviews/sec):585.0 #Correct:145 #Tested:290 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:29.0% Speed(reviews/sec):585.4 #Correct:146 #Tested:291 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:29.1% Speed(reviews/sec):585.7 #Correct:146 #Tested:292 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:29.2% Speed(reviews/sec):586.2 #Correct:147 #Tested:293 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:29.3% Speed(reviews/sec):586.5 #Correct:147 #Tested:294 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:29.4% Speed(reviews/sec):586.8 #Correct:148 #Tested:295 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:29.5% Speed(reviews/sec):587.3 #Correct:148 #Tested:296 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:29.6% Speed(reviews/sec):587.8 #Correct:149 #Tested:297 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:29.7% Speed(reviews/sec):587.6 #Correct:149 #Tested:298 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:29.8% Speed(reviews/sec):587.6 #Correct:150 #Tested:299 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:29.9% Speed(reviews/sec):587.7 #Correct:150 #Tested:300 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:30.0% Speed(reviews/sec):587.8 #Correct:151 #Tested:301 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:30.1% Speed(reviews/sec):587.5 #Correct:151 #Tested:302 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:30.2% Speed(reviews/sec):586.4 #Correct:152 #Tested:303 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:30.3% Speed(reviews/sec):586.6 #Correct:152 #Tested:304 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:30.4% Speed(reviews/sec):587.0 #Correct:153 #Tested:305 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:30.5% Speed(reviews/sec):587.3 #Correct:153 #Tested:306 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:30.6% Speed(reviews/sec):586.2 #Correct:154 #Tested:307 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:30.7% Speed(reviews/sec):586.5 #Correct:154 #Tested:308 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:30.8% Speed(reviews/sec):586.6 #Correct:155 #Tested:309 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:30.9% Speed(reviews/sec):586.2 #Correct:155 #Tested:310 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:31.0% Speed(reviews/sec):586.7 #Correct:156 #Tested:311 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:31.1% Speed(reviews/sec):586.8 #Correct:156 #Tested:312 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:31.2% Speed(reviews/sec):587.2 #Correct:157 #Tested:313 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:31.3% Speed(reviews/sec):587.2 #Correct:157 #Tested:314 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:31.4% Speed(reviews/sec):587.5 #Correct:158 #Tested:315 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:31.5% Speed(reviews/sec):587.5 #Correct:158 #Tested:316 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:31.6% Speed(reviews/sec):587.6 #Correct:159 #Tested:317 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:31.7% Speed(reviews/sec):587.4 #Correct:159 #Tested:318 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:31.8% Speed(reviews/sec):587.5 #Correct:160 #Tested:319 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:31.9% Speed(reviews/sec):587.7 #Correct:160 #Tested:320 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:32.0% Speed(reviews/sec):588.1 #Correct:161 #Tested:321 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:32.1% Speed(reviews/sec):588.4 #Correct:161 #Tested:322 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:32.2% Speed(reviews/sec):588.7 #Correct:162 #Tested:323 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:32.3% Speed(reviews/sec):588.8 #Correct:162 #Tested:324 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:32.4% Speed(reviews/sec):588.7 #Correct:163 #Tested:325 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:32.5% Speed(reviews/sec):588.8 #Correct:163 #Tested:326 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:32.6% Speed(reviews/sec):589.1 #Correct:164 #Tested:327 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:32.7% Speed(reviews/sec):588.9 #Correct:164 #Tested:328 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:32.8% Speed(reviews/sec):588.9 #Correct:165 #Tested:329 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:32.9% Speed(reviews/sec):589.2 #Correct:165 #Tested:330 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:33.0% Speed(reviews/sec):589.4 #Correct:166 #Tested:331 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:33.1% Speed(reviews/sec):589.6 #Correct:166 #Tested:332 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:33.2% Speed(reviews/sec):589.7 #Correct:167 #Tested:333 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:33.3% Speed(reviews/sec):589.9 #Correct:167 #Tested:334 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:33.4% Speed(reviews/sec):589.3 #Correct:168 #Tested:335 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:33.5% Speed(reviews/sec):589.5 #Correct:168 #Tested:336 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:33.6% Speed(reviews/sec):589.5 #Correct:169 #Tested:337 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:33.7% Speed(reviews/sec):589.7 #Correct:169 #Tested:338 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:33.8% Speed(reviews/sec):589.9 #Correct:170 #Tested:339 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:33.9% Speed(reviews/sec):590.1 #Correct:170 #Tested:340 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:34.0% Speed(reviews/sec):589.9 #Correct:171 #Tested:341 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:34.1% Speed(reviews/sec):590.2 #Correct:171 #Tested:342 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:34.2% Speed(reviews/sec):589.3 #Correct:172 #Tested:343 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:34.3% Speed(reviews/sec):589.6 #Correct:172 #Tested:344 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:34.4% Speed(reviews/sec):589.3 #Correct:173 #Tested:345 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:34.5% Speed(reviews/sec):589.5 #Correct:173 #Tested:346 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:34.6% Speed(reviews/sec):589.7 #Correct:174 #Tested:347 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:34.7% Speed(reviews/sec):589.9 #Correct:174 #Tested:348 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:34.8% Speed(reviews/sec):590.0 #Correct:175 #Tested:349 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:34.9% Speed(reviews/sec):590.1 #Correct:175 #Tested:350 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:35.0% Speed(reviews/sec):590.4 #Correct:176 #Tested:351 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:35.1% Speed(reviews/sec):590.5 #Correct:176 #Tested:352 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:35.2% Speed(reviews/sec):590.4 #Correct:177 #Tested:353 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:35.3% Speed(reviews/sec):590.6 #Correct:177 #Tested:354 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:35.4% Speed(reviews/sec):590.8 #Correct:178 #Tested:355 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:35.5% Speed(reviews/sec):590.1 #Correct:178 #Tested:356 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:35.6% Speed(reviews/sec):590.0 #Correct:179 #Tested:357 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:35.7% Speed(reviews/sec):589.7 #Correct:179 #Tested:358 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:35.8% Speed(reviews/sec):589.8 #Correct:180 #Tested:359 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:35.9% Speed(reviews/sec):590.0 #Correct:180 #Tested:360 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:36.0% Speed(reviews/sec):586.7 #Correct:181 #Tested:361 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:36.1% Speed(reviews/sec):586.4 #Correct:181 #Tested:362 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:36.2% Speed(reviews/sec):585.6 #Correct:182 #Tested:363 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:36.3% Speed(reviews/sec):585.7 #Correct:182 #Tested:364 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:36.4% Speed(reviews/sec):585.9 #Correct:183 #Tested:365 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:36.5% Speed(reviews/sec):586.0 #Correct:183 #Tested:366 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:36.6% Speed(reviews/sec):586.2 #Correct:184 #Tested:367 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:36.7% Speed(reviews/sec):586.5 #Correct:184 #Tested:368 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:36.8% Speed(reviews/sec):586.5 #Correct:185 #Tested:369 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:36.9% Speed(reviews/sec):586.7 #Correct:185 #Tested:370 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:37.0% Speed(reviews/sec):586.7 #Correct:186 #Tested:371 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:37.1% Speed(reviews/sec):586.0 #Correct:186 #Tested:372 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:37.2% Speed(reviews/sec):586.1 #Correct:187 #Tested:373 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:37.3% Speed(reviews/sec):586.4 #Correct:187 #Tested:374 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:37.4% Speed(reviews/sec):586.1 #Correct:188 #Tested:375 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:37.5% Speed(reviews/sec):586.2 #Correct:188 #Tested:376 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:37.6% Speed(reviews/sec):586.4 #Correct:189 #Tested:377 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:37.7% Speed(reviews/sec):586.5 #Correct:189 #Tested:378 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:37.8% Speed(reviews/sec):586.8 #Correct:190 #Tested:379 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:37.9% Speed(reviews/sec):587.1 #Correct:190 #Tested:380 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:38.0% Speed(reviews/sec):586.5 #Correct:191 #Tested:381 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:38.1% Speed(reviews/sec):586.6 #Correct:191 #Tested:382 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:38.2% Speed(reviews/sec):586.5 #Correct:192 #Tested:383 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:38.3% Speed(reviews/sec):586.7 #Correct:192 #Tested:384 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:38.4% Speed(reviews/sec):586.8 #Correct:193 #Tested:385 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:38.5% Speed(reviews/sec):587.1 #Correct:193 #Tested:386 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:38.6% Speed(reviews/sec):587.1 #Correct:194 #Tested:387 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:38.7% Speed(reviews/sec):587.4 #Correct:194 #Tested:388 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:38.8% Speed(reviews/sec):587.6 #Correct:195 #Tested:389 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:38.9% Speed(reviews/sec):587.8 #Correct:195 #Tested:390 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:39.0% Speed(reviews/sec):587.9 #Correct:196 #Tested:391 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:39.1% Speed(reviews/sec):588.0 #Correct:196 #Tested:392 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:39.2% Speed(reviews/sec):588.2 #Correct:197 #Tested:393 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:39.3% Speed(reviews/sec):588.1 #Correct:197 #Tested:394 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:39.4% Speed(reviews/sec):588.0 #Correct:198 #Tested:395 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:39.5% Speed(reviews/sec):588.2 #Correct:198 #Tested:396 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:39.6% Speed(reviews/sec):588.3 #Correct:199 #Tested:397 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:39.7% Speed(reviews/sec):588.5 #Correct:199 #Tested:398 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:39.8% Speed(reviews/sec):588.4 #Correct:200 #Tested:399 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:39.9% Speed(reviews/sec):588.6 #Correct:200 #Tested:400 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:40.0% Speed(reviews/sec):588.3 #Correct:201 #Tested:401 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:40.1% Speed(reviews/sec):588.6 #Correct:201 #Tested:402 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:40.2% Speed(reviews/sec):588.6 #Correct:202 #Tested:403 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:40.3% Speed(reviews/sec):588.9 #Correct:202 #Tested:404 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:40.4% Speed(reviews/sec):589.1 #Correct:203 #Tested:405 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:40.5% Speed(reviews/sec):589.2 #Correct:203 #Tested:406 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:40.6% Speed(reviews/sec):589.2 #Correct:204 #Tested:407 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:40.7% Speed(reviews/sec):589.4 #Correct:204 #Tested:408 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:40.8% Speed(reviews/sec):589.4 #Correct:205 #Tested:409 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:40.9% Speed(reviews/sec):589.5 #Correct:205 #Tested:410 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:41.0% Speed(reviews/sec):589.6 #Correct:206 #Tested:411 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:41.1% Speed(reviews/sec):589.5 #Correct:206 #Tested:412 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:41.2% Speed(reviews/sec):589.8 #Correct:207 #Tested:413 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:41.3% Speed(reviews/sec):589.6 #Correct:207 #Tested:414 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:41.4% Speed(reviews/sec):589.7 #Correct:208 #Tested:415 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:41.5% Speed(reviews/sec):589.8 #Correct:208 #Tested:416 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:41.6% Speed(reviews/sec):590.0 #Correct:209 #Tested:417 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:41.7% Speed(reviews/sec):590.0 #Correct:209 #Tested:418 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:41.8% Speed(reviews/sec):590.1 #Correct:210 #Tested:419 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:41.9% Speed(reviews/sec):590.2 #Correct:210 #Tested:420 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:42.0% Speed(reviews/sec):590.0 #Correct:211 #Tested:421 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:42.1% Speed(reviews/sec):590.1 #Correct:211 #Tested:422 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:42.2% Speed(reviews/sec):590.3 #Correct:212 #Tested:423 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:42.3% Speed(reviews/sec):590.4 #Correct:212 #Tested:424 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:42.4% Speed(reviews/sec):590.5 #Correct:213 #Tested:425 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:42.5% Speed(reviews/sec):590.8 #Correct:213 #Tested:426 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:42.6% Speed(reviews/sec):590.4 #Correct:214 #Tested:427 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:42.7% Speed(reviews/sec):590.4 #Correct:214 #Tested:428 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:42.8% Speed(reviews/sec):590.4 #Correct:215 #Tested:429 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:42.9% Speed(reviews/sec):590.5 #Correct:215 #Tested:430 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:43.0% Speed(reviews/sec):590.7 #Correct:216 #Tested:431 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:43.1% Speed(reviews/sec):590.9 #Correct:216 #Tested:432 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:43.2% Speed(reviews/sec):590.9 #Correct:217 #Tested:433 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:43.3% Speed(reviews/sec):591.1 #Correct:217 #Tested:434 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:43.4% Speed(reviews/sec):591.2 #Correct:218 #Tested:435 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:43.5% Speed(reviews/sec):591.2 #Correct:218 #Tested:436 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:43.6% Speed(reviews/sec):591.4 #Correct:219 #Tested:437 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:43.7% Speed(reviews/sec):591.1 #Correct:219 #Tested:438 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:43.8% Speed(reviews/sec):591.4 #Correct:220 #Tested:439 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:43.9% Speed(reviews/sec):591.2 #Correct:220 #Tested:440 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:44.0% Speed(reviews/sec):591.0 #Correct:221 #Tested:441 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:44.1% Speed(reviews/sec):591.1 #Correct:221 #Tested:442 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:44.2% Speed(reviews/sec):591.4 #Correct:222 #Tested:443 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:44.3% Speed(reviews/sec):591.5 #Correct:222 #Tested:444 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:44.4% Speed(reviews/sec):591.0 #Correct:223 #Tested:445 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:44.5% Speed(reviews/sec):591.2 #Correct:223 #Tested:446 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:44.6% Speed(reviews/sec):591.2 #Correct:224 #Tested:447 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:44.7% Speed(reviews/sec):591.1 #Correct:224 #Tested:448 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:44.8% Speed(reviews/sec):591.2 #Correct:225 #Tested:449 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:44.9% Speed(reviews/sec):591.1 #Correct:225 #Tested:450 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:45.0% Speed(reviews/sec):591.4 #Correct:226 #Tested:451 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:45.1% Speed(reviews/sec):590.8 #Correct:226 #Tested:452 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:45.2% Speed(reviews/sec):591.1 #Correct:227 #Tested:453 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:45.3% Speed(reviews/sec):591.3 #Correct:227 #Tested:454 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:45.4% Speed(reviews/sec):591.6 #Correct:228 #Tested:455 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:45.5% Speed(reviews/sec):591.8 #Correct:228 #Tested:456 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:45.6% Speed(reviews/sec):592.0 #Correct:229 #Tested:457 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:45.7% Speed(reviews/sec):592.3 #Correct:229 #Tested:458 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:45.8% Speed(reviews/sec):592.4 #Correct:230 #Tested:459 Testing Accuracy:50.1%[[ 0.5]]
# POSITIVE
# Progress:45.9% Speed(reviews/sec):592.3 #Correct:230 #Tested:460 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# ...
# POSITIVE
# Progress:84.8% Speed(reviews/sec):584.0 #Correct:425 #Tested:849 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:84.9% Speed(reviews/sec):583.8 #Correct:425 #Tested:850 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.0% Speed(reviews/sec):583.6 #Correct:426 #Tested:851 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.1% Speed(reviews/sec):583.7 #Correct:426 #Tested:852 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.2% Speed(reviews/sec):583.6 #Correct:427 #Tested:853 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.3% Speed(reviews/sec):583.6 #Correct:427 #Tested:854 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.4% Speed(reviews/sec):583.6 #Correct:428 #Tested:855 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.5% Speed(reviews/sec):583.7 #Correct:428 #Tested:856 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.6% Speed(reviews/sec):583.8 #Correct:429 #Tested:857 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.7% Speed(reviews/sec):583.8 #Correct:429 #Tested:858 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.8% Speed(reviews/sec):583.8 #Correct:430 #Tested:859 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:85.9% Speed(reviews/sec):583.8 #Correct:430 #Tested:860 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.0% Speed(reviews/sec):583.9 #Correct:431 #Tested:861 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.1% Speed(reviews/sec):583.9 #Correct:431 #Tested:862 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.2% Speed(reviews/sec):584.0 #Correct:432 #Tested:863 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.3% Speed(reviews/sec):583.4 #Correct:432 #Tested:864 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.4% Speed(reviews/sec):583.4 #Correct:433 #Tested:865 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.5% Speed(reviews/sec):583.4 #Correct:433 #Tested:866 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.6% Speed(reviews/sec):583.4 #Correct:434 #Tested:867 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.7% Speed(reviews/sec):583.5 #Correct:434 #Tested:868 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.8% Speed(reviews/sec):583.6 #Correct:435 #Tested:869 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:86.9% Speed(reviews/sec):583.8 #Correct:435 #Tested:870 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.0% Speed(reviews/sec):583.8 #Correct:436 #Tested:871 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.1% Speed(reviews/sec):583.8 #Correct:436 #Tested:872 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.2% Speed(reviews/sec):583.9 #Correct:437 #Tested:873 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.3% Speed(reviews/sec):584.0 #Correct:437 #Tested:874 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.4% Speed(reviews/sec):584.1 #Correct:438 #Tested:875 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.5% Speed(reviews/sec):584.2 #Correct:438 #Tested:876 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.6% Speed(reviews/sec):584.4 #Correct:439 #Tested:877 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.7% Speed(reviews/sec):583.9 #Correct:439 #Tested:878 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.8% Speed(reviews/sec):584.1 #Correct:440 #Tested:879 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:87.9% Speed(reviews/sec):584.1 #Correct:440 #Tested:880 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.0% Speed(reviews/sec):584.2 #Correct:441 #Tested:881 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.1% Speed(reviews/sec):584.3 #Correct:441 #Tested:882 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.2% Speed(reviews/sec):584.3 #Correct:442 #Tested:883 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.3% Speed(reviews/sec):584.4 #Correct:442 #Tested:884 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.4% Speed(reviews/sec):584.4 #Correct:443 #Tested:885 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.5% Speed(reviews/sec):584.5 #Correct:443 #Tested:886 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.6% Speed(reviews/sec):584.7 #Correct:444 #Tested:887 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.7% Speed(reviews/sec):584.7 #Correct:444 #Tested:888 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.8% Speed(reviews/sec):584.8 #Correct:445 #Tested:889 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:88.9% Speed(reviews/sec):584.7 #Correct:445 #Tested:890 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.0% Speed(reviews/sec):584.8 #Correct:446 #Tested:891 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.1% Speed(reviews/sec):584.8 #Correct:446 #Tested:892 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.2% Speed(reviews/sec):584.9 #Correct:447 #Tested:893 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.3% Speed(reviews/sec):585.0 #Correct:447 #Tested:894 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.4% Speed(reviews/sec):585.1 #Correct:448 #Tested:895 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.5% Speed(reviews/sec):585.2 #Correct:448 #Tested:896 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.6% Speed(reviews/sec):585.3 #Correct:449 #Tested:897 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.7% Speed(reviews/sec):585.4 #Correct:449 #Tested:898 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.8% Speed(reviews/sec):585.2 #Correct:450 #Tested:899 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:89.9% Speed(reviews/sec):585.2 #Correct:450 #Tested:900 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.0% Speed(reviews/sec):585.2 #Correct:451 #Tested:901 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.1% Speed(reviews/sec):585.0 #Correct:451 #Tested:902 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.2% Speed(reviews/sec):584.9 #Correct:452 #Tested:903 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.3% Speed(reviews/sec):585.0 #Correct:452 #Tested:904 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.4% Speed(reviews/sec):585.1 #Correct:453 #Tested:905 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.5% Speed(reviews/sec):585.2 #Correct:453 #Tested:906 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.6% Speed(reviews/sec):585.3 #Correct:454 #Tested:907 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.7% Speed(reviews/sec):585.3 #Correct:454 #Tested:908 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.8% Speed(reviews/sec):585.4 #Correct:455 #Tested:909 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:90.9% Speed(reviews/sec):585.5 #Correct:455 #Tested:910 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.0% Speed(reviews/sec):585.5 #Correct:456 #Tested:911 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.1% Speed(reviews/sec):585.5 #Correct:456 #Tested:912 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.2% Speed(reviews/sec):585.6 #Correct:457 #Tested:913 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.3% Speed(reviews/sec):585.5 #Correct:457 #Tested:914 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.4% Speed(reviews/sec):585.6 #Correct:458 #Tested:915 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.5% Speed(reviews/sec):585.6 #Correct:458 #Tested:916 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.6% Speed(reviews/sec):585.6 #Correct:459 #Tested:917 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.7% Speed(reviews/sec):585.7 #Correct:459 #Tested:918 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.8% Speed(reviews/sec):585.7 #Correct:460 #Tested:919 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:91.9% Speed(reviews/sec):585.7 #Correct:460 #Tested:920 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.0% Speed(reviews/sec):585.7 #Correct:461 #Tested:921 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.1% Speed(reviews/sec):585.8 #Correct:461 #Tested:922 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.2% Speed(reviews/sec):585.8 #Correct:462 #Tested:923 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.3% Speed(reviews/sec):586.0 #Correct:462 #Tested:924 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.4% Speed(reviews/sec):586.1 #Correct:463 #Tested:925 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.5% Speed(reviews/sec):586.1 #Correct:463 #Tested:926 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.6% Speed(reviews/sec):586.2 #Correct:464 #Tested:927 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.7% Speed(reviews/sec):586.3 #Correct:464 #Tested:928 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.8% Speed(reviews/sec):586.4 #Correct:465 #Tested:929 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:92.9% Speed(reviews/sec):586.4 #Correct:465 #Tested:930 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.0% Speed(reviews/sec):586.5 #Correct:466 #Tested:931 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.1% Speed(reviews/sec):586.4 #Correct:466 #Tested:932 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.2% Speed(reviews/sec):586.5 #Correct:467 #Tested:933 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.3% Speed(reviews/sec):586.5 #Correct:467 #Tested:934 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.4% Speed(reviews/sec):586.5 #Correct:468 #Tested:935 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.5% Speed(reviews/sec):586.6 #Correct:468 #Tested:936 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.6% Speed(reviews/sec):586.7 #Correct:469 #Tested:937 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.7% Speed(reviews/sec):586.8 #Correct:469 #Tested:938 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.8% Speed(reviews/sec):586.8 #Correct:470 #Tested:939 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:93.9% Speed(reviews/sec):586.9 #Correct:470 #Tested:940 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.0% Speed(reviews/sec):587.0 #Correct:471 #Tested:941 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.1% Speed(reviews/sec):587.0 #Correct:471 #Tested:942 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.2% Speed(reviews/sec):587.1 #Correct:472 #Tested:943 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.3% Speed(reviews/sec):587.1 #Correct:472 #Tested:944 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.4% Speed(reviews/sec):586.9 #Correct:473 #Tested:945 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.5% Speed(reviews/sec):587.0 #Correct:473 #Tested:946 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.6% Speed(reviews/sec):587.0 #Correct:474 #Tested:947 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.7% Speed(reviews/sec):587.1 #Correct:474 #Tested:948 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.8% Speed(reviews/sec):587.2 #Correct:475 #Tested:949 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:94.9% Speed(reviews/sec):587.3 #Correct:475 #Tested:950 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.0% Speed(reviews/sec):587.4 #Correct:476 #Tested:951 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.1% Speed(reviews/sec):587.2 #Correct:476 #Tested:952 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.2% Speed(reviews/sec):587.2 #Correct:477 #Tested:953 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.3% Speed(reviews/sec):587.3 #Correct:477 #Tested:954 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.4% Speed(reviews/sec):587.2 #Correct:478 #Tested:955 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.5% Speed(reviews/sec):587.2 #Correct:478 #Tested:956 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.6% Speed(reviews/sec):587.2 #Correct:479 #Tested:957 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.7% Speed(reviews/sec):585.9 #Correct:479 #Tested:958 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.8% Speed(reviews/sec):585.7 #Correct:480 #Tested:959 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:95.9% Speed(reviews/sec):585.7 #Correct:480 #Tested:960 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.0% Speed(reviews/sec):585.6 #Correct:481 #Tested:961 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.1% Speed(reviews/sec):585.7 #Correct:481 #Tested:962 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.2% Speed(reviews/sec):585.8 #Correct:482 #Tested:963 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.3% Speed(reviews/sec):585.8 #Correct:482 #Tested:964 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.4% Speed(reviews/sec):585.9 #Correct:483 #Tested:965 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.5% Speed(reviews/sec):586.0 #Correct:483 #Tested:966 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.6% Speed(reviews/sec):586.1 #Correct:484 #Tested:967 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.7% Speed(reviews/sec):586.2 #Correct:484 #Tested:968 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.8% Speed(reviews/sec):586.3 #Correct:485 #Tested:969 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:96.9% Speed(reviews/sec):586.4 #Correct:485 #Tested:970 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.0% Speed(reviews/sec):586.4 #Correct:486 #Tested:971 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.1% Speed(reviews/sec):586.5 #Correct:486 #Tested:972 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.2% Speed(reviews/sec):586.5 #Correct:487 #Tested:973 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.3% Speed(reviews/sec):586.5 #Correct:487 #Tested:974 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.4% Speed(reviews/sec):586.5 #Correct:488 #Tested:975 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.5% Speed(reviews/sec):586.5 #Correct:488 #Tested:976 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.6% Speed(reviews/sec):586.5 #Correct:489 #Tested:977 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.7% Speed(reviews/sec):586.4 #Correct:489 #Tested:978 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.8% Speed(reviews/sec):586.5 #Correct:490 #Tested:979 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:97.9% Speed(reviews/sec):586.5 #Correct:490 #Tested:980 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.0% Speed(reviews/sec):586.6 #Correct:491 #Tested:981 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.1% Speed(reviews/sec):586.4 #Correct:491 #Tested:982 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.2% Speed(reviews/sec):586.4 #Correct:492 #Tested:983 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.3% Speed(reviews/sec):586.2 #Correct:492 #Tested:984 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.4% Speed(reviews/sec):586.2 #Correct:493 #Tested:985 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.5% Speed(reviews/sec):586.4 #Correct:493 #Tested:986 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.6% Speed(reviews/sec):586.4 #Correct:494 #Tested:987 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.7% Speed(reviews/sec):586.5 #Correct:494 #Tested:988 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.8% Speed(reviews/sec):586.6 #Correct:495 #Tested:989 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:98.9% Speed(reviews/sec):586.5 #Correct:495 #Tested:990 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.0% Speed(reviews/sec):586.6 #Correct:496 #Tested:991 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.1% Speed(reviews/sec):586.7 #Correct:496 #Tested:992 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.2% Speed(reviews/sec):586.8 #Correct:497 #Tested:993 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.3% Speed(reviews/sec):586.8 #Correct:497 #Tested:994 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.4% Speed(reviews/sec):586.7 #Correct:498 #Tested:995 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.5% Speed(reviews/sec):586.7 #Correct:498 #Tested:996 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.6% Speed(reviews/sec):586.7 #Correct:499 #Tested:997 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.7% Speed(reviews/sec):586.7 #Correct:499 #Tested:998 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.8% Speed(reviews/sec):586.7 #Correct:500 #Tested:999 Testing Accuracy:50.0%[[ 0.5]]
# POSITIVE
# Progress:99.9% Speed(reviews/sec):586.8 #Correct:500 #Tested:1000 Testing Accuracy:50.0%

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# 24000
# (72810, 10)
# (10, 1)
# (1, 72810)
# (1, 10)
# (1, 1)
# ()
# (1, 1)
# (1, 1)
# (1, 10)
# (1, 10)
# (10, 1) (1, 1)
# (72810, 1) (1, 10)
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):206.4 #Correct:1251 #Trained:2501 Training Accuracy:50.0%
# Progress:20.8% Speed(reviews/sec):203.6 #Correct:2501 #Trained:5001 Training Accuracy:50.0%
# Progress:31.2% Speed(reviews/sec):203.3 #Correct:3751 #Trained:7501 Training Accuracy:50.0%
# Progress:41.6% Speed(reviews/sec):201.9 #Correct:5001 #Trained:10001 Training Accuracy:50.0%
# Progress:52.0% Speed(reviews/sec):200.9 #Correct:6251 #Trained:12501 Training Accuracy:50.0%
# Progress:62.5% Speed(reviews/sec):201.5 #Correct:7501 #Trained:15001 Training Accuracy:50.0%
# Progress:72.9% Speed(reviews/sec):202.5 #Correct:8751 #Trained:17501 Training Accuracy:50.0%
# Progress:83.3% Speed(reviews/sec):203.0 #Correct:10001 #Trained:20001 Training Accuracy:50.0%
# Progress:93.7% Speed(reviews/sec):203.7 #Correct:11251 #Trained:22501 Training Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):204.2 #Correct:12000 #Trained:24000 Training Accuracy:50.0%

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):212.7 #Correct:1248 #Trained:2501 Training Accuracy:49.9%
# Progress:20.8% Speed(reviews/sec):208.1 #Correct:2498 #Trained:5001 Training Accuracy:49.9%
# Progress:31.2% Speed(reviews/sec):210.5 #Correct:3748 #Trained:7501 Training Accuracy:49.9%
# Progress:41.6% Speed(reviews/sec):210.9 #Correct:4998 #Trained:10001 Training Accuracy:49.9%
# Progress:52.0% Speed(reviews/sec):208.7 #Correct:6248 #Trained:12501 Training Accuracy:49.9%
# Progress:62.5% Speed(reviews/sec):208.1 #Correct:7497 #Trained:15001 Training Accuracy:49.9%
# Progress:65.7% Speed(reviews/sec):207.9 #Correct:7892 #Trained:15791 Training Accuracy:49.9%
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:105: RuntimeWarning: overflow encountered in exp
# Progress:72.9% Speed(reviews/sec):207.9 #Correct:8757 #Trained:17501 Training Accuracy:50.0%
# Progress:83.3% Speed(reviews/sec):208.2 #Correct:10006 #Trained:20001 Training Accuracy:50.0%
# Progress:93.7% Speed(reviews/sec):211.1 #Correct:11256 #Trained:22501 Training Accuracy:50.0%
# Progress:99.9% Speed(reviews/sec):212.8 #Correct:12006 #Trained:24000 Training Accuracy:50.0%

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# 24000
# (72810, 10)
# (10, 1)
# (1, 72810)
# (1, 10)
# (1, 1)
# ()
# (1, 1)
# (1, 1)
# (1, 10)
# (1, 10)
# (10, 1) (1, 1)
# (72810, 1) (1, 10)
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:1 #Trained:1 Training Accuracy:100.%
# Progress:10.4% Speed(reviews/sec):203.9 #Correct:1264 #Trained:2501 Training Accuracy:50.5%
# Progress:20.8% Speed(reviews/sec):209.1 #Correct:2568 #Trained:5001 Training Accuracy:51.3%
# Progress:31.2% Speed(reviews/sec):205.1 #Correct:3911 #Trained:7501 Training Accuracy:52.1%
# Progress:41.6% Speed(reviews/sec):204.9 #Correct:5412 #Trained:10001 Training Accuracy:54.1%
# Progress:52.0% Speed(reviews/sec):203.7 #Correct:6953 #Trained:12501 Training Accuracy:55.6%
# Progress:62.5% Speed(reviews/sec):202.9 #Correct:8540 #Trained:15001 Training Accuracy:56.9%
# Progress:72.9% Speed(reviews/sec):204.1 #Correct:10149 #Trained:17501 Training Accuracy:57.9%
# Progress:83.3% Speed(reviews/sec):204.1 #Correct:11817 #Trained:20001 Training Accuracy:59.0%
# Progress:93.7% Speed(reviews/sec):204.7 #Correct:13498 #Trained:22501 Training Accuracy:59.9%
# Progress:99.9% Speed(reviews/sec):205.1 #Correct:14569 #Trained:24000 Training Accuracy:60.7%

# %% [markdown]
# With a learning rate of `0.001`, the network should finall have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
